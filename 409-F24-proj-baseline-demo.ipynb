# %% [markdown]
# # Overview of baseline code for morphological inflection
# LING 409 Fall 2024

# %%
import nonneural  # import nonneural module to have access to functions defined in it
import random # for doing some testing
import os

# %% [markdown]
# In this notebook, I'll start to demonstrate how I might work through the `nonneural.py` code to understand what it is doing.
#
# We can display the text of the `nonneural.py` Python script in this Jupyter notebook using the [magic command `%pycat`](https://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-pycat).

# %%
# %pycat nonneural.py
# Out:
# #!/usr/bin/env python3
# """
# Non-neural baseline system for the SIGMORPHON 2020 Shared Task 0.
# Author: Mans Hulden
# Modified by: Tiago Pimentel
# Modified by: Jordan Kodner
# Modified by: Omer Goldman
# Last Update: 22/03/2021
# """
#
# import sys, os, getopt, re
# from functools import wraps
# from glob import glob
#
#
# def hamming(s,t):
#     return sum(1 for x,y in zip(s,t) if x != y)
#
#
# def halign(s,t):
#     """Align two strings by Hamming distance."""
#     slen = len(s)
#     tlen = len(t)
#     minscore = len(s) + len(t) + 1
#     for upad in range(0, len(t)+1):
#         upper = '_' * upad + s + (len(t) - upad) * '_'
#         lower = len(s) * '_' + t
#         score = hamming(upper, lower)
#         if score < minscore:
#             bu = upper
#             bl = lower
#             minscore = score
#
#     for lpad in range(0, len(s)+1):
#         upper = len(t) * '_' + s
#         lower = (len(s) - lpad) * '_' + t + '_' * lpad
#         score = hamming(upper, lower)
#         if score < minscore:
#             bu = upper
#             bl = lower
#             minscore = score
#
#     zipped = list(zip(bu,bl))
#     newin  = ''.join(i for i,o in zipped if i != '_' or o != '_')
#     newout = ''.join(o for i,o in zipped if i != '_' or o != '_')
#     return newin, newout
#
#
# def levenshtein(s, t, inscost = 1.0, delcost = 1.0, substcost = 1.0):
#     """Recursive implementation of Levenshtein, with alignments returned."""
#     @memolrec
#     def lrec(spast, tpast, srem, trem, cost):
#         if len(srem) == 0:
#             return spast + len(trem) * '_', tpast + trem, '', '', cost + len(trem)
#         if len(trem) == 0:
#             return spast + srem, tpast + len(srem) * '_', '', '', cost + len(srem)
#
#         addcost = 0
#         if srem[0] != trem[0]:
#             addcost = substcost
#
#         return min((lrec(spast + srem[0], tpast + trem[0], srem[1:], trem[1:], cost + addcost),
#                    lrec(spast + '_', tpast + trem[0], srem, trem[1:], cost + inscost),
#                    lrec(spast + srem[0], tpast + '_', srem[1:], trem, cost + delcost)),
#                    key = lambda x: x[4])
#
#     answer = lrec('', '', s, t, 0)
#     return answer[0],answer[1],answer[4]
#
#
# def memolrec(func):
#     """Memoizer for Levenshtein."""
#     cache = {}
#     @wraps(func)
#     def wrap(sp, tp, sr, tr, cost):
#         if (sr,tr) not in cache:
#             res = func(sp, tp, sr, tr, cost)
#             cache[(sr,tr)] = (res[0][len(sp):], res[1][len(tp):], res[4] - cost)
#         return sp + cache[(sr,tr)][0], tp + cache[(sr,tr)][1], '', '', cost + cache[(sr,tr)][2]
#     return wrap
#
#
# def alignprs(lemma, form):
#     """Break lemma/form into three parts:
#     IN:  1 | 2 | 3
#     OUT: 4 | 5 | 6
#     1/4 are assumed to be prefixes, 2/5 the stem, and 3/6 a suffix.
#     1/4 and 3/6 may be empty.
#     """
#
#     al = levenshtein(lemma, form, substcost = 1.1) # Force preference of 0:x or x:0 by 1.1 cost
#     alemma, aform = al[0], al[1]
#     # leading spaces
#     lspace = max(len(alemma) - len(alemma.lstrip('_')), len(aform) - len(aform.lstrip('_')))
#     # trailing spaces
#     tspace = max(len(alemma[::-1]) - len(alemma[::-1].lstrip('_')), len(aform[::-1]) - len(aform[::-1].lstrip('_')))
#     return alemma[0:lspace], alemma[lspace:len(alemma)-tspace], alemma[len(alemma)-tspace:], aform[0:lspace], aform[lspace:len(alemma)-tspace], aform[len(alemma)-tspace:]
#
#
# def prefix_suffix_rules_get(lemma, form):
#     """Extract a number of suffix-change and prefix-change rules
#     based on a given example lemma+inflected form."""
#     lp,lr,ls,fp,fr,fs = alignprs(lemma, form) # Get six parts, three for in three for out
#
#     # Suffix rules
#     ins  = lr + ls + ">"
#     outs = fr + fs + ">"
#     srules = set()
#     for i in range(min(len(ins), len(outs))):
#         srules.add((ins[i:], outs[i:]))
#     srules = {(x[0].replace('_',''), x[1].replace('_','')) for x in srules}
#
#     # Prefix rules
#     prules = set()
#     if len(lp) >= 0 or len(fp) >= 0:
#         inp = "<" + lp
#         outp = "<" + fp
#         for i in range(0,len(fr)):
#             prules.add((inp + fr[:i],outp + fr[:i]))
#             prules = {(x[0].replace('_',''), x[1].replace('_','')) for x in prules}
#
#     return prules, srules
#
#
# def apply_best_rule(lemma, msd, allprules, allsrules):
#     """Applies the longest-matching suffix-changing rule given an input
#     form and the MSD. Length ties in suffix rules are broken by frequency.
#     For prefix-changing rules, only the most frequent rule is chosen."""
#
#     bestrulelen = 0
#     base = "<" + lemma + ">"
#     if msd not in allprules and msd not in allsrules:
#         return lemma # Haven't seen this inflection, so bail out
#
#     if msd in allsrules:
#         applicablerules = [(x[0],x[1],y) for x,y in allsrules[msd].items() if x[0] in base]
#         if applicablerules:
#             bestrule = max(applicablerules, key = lambda x: (len(x[0]), x[2], len(x[1])))
#             base = base.replace(bestrule[0], bestrule[1])
#
#     if msd in allprules:
#         applicablerules = [(x[0],x[1],y) for x,y in allprules[msd].items() if x[0] in base]
#         if applicablerules:
#             bestrule = max(applicablerules, key = lambda x: (x[2]))
#             base = base.replace(bestrule[0], bestrule[1])
#
#     base = base.replace('<', '')
#     base = base.replace('>', '')
#     return base
#
#
# def numleadingsyms(s, symbol):
#     return len(s) - len(s.lstrip(symbol))
#
#
# def numtrailingsyms(s, symbol):
#     return len(s) - len(s.rstrip(symbol))
#
# ###############################################################################
#
#
# def main(argv):
#     options, remainder = getopt.gnu_getopt(argv[1:], 'ohp:', ['output','help','path='])
#     TEST, OUTPUT, HELP, path = False,False, False, 'data/'
#     for opt, arg in options:
#         if opt in ('-o', '--output'):
#             OUTPUT = True
#         if opt in ('-t', '--test'):
#             TEST = True
#         if opt in ('-h', '--help'):
#             HELP = True
#         if opt in ('-p', '--path'):
#             path = arg
#
#     if HELP:
#             print("\n*** Baseline for the SIGMORPHON 2020 shared task ***\n")
#             print("By default, the program runs all languages only evaluating accuracy.")
#             print("To create output files, use -o")
#             print("The training and dev-data are assumed to live in ./part1/development_languages/")
#             print("Options:")
#             print(" -o         create output files with guesses (and don't just evaluate)")
#             print(" -t         evaluate on test instead of dev")
#             print(" -p [path]  data files path. Default is ../data/")
#             quit()
#
#     totalavg, numlang = 0.0, 0
#     for lang in [os.path.splitext(d)[0] for d in os.listdir(path) if '.trn' in d]:
#         allprules, allsrules = {}, {}
#         if not os.path.isfile(path + lang +  ".trn"):
#             continue
#         lines = [line.strip() for line in open(path + lang + ".trn", "r", encoding='utf8') if line != '\n']
#
#         # First, test if language is predominantly suffixing or prefixing
#         # If prefixing, work with reversed strings
#         prefbias, suffbias = 0,0
#         for l in lines:
#             lemma, _, form = l.split(u'\t')
#             aligned = halign(lemma, form)
#             if ' ' not in aligned[0] and ' ' not in aligned[1] and '-' not in aligned[0] and '-' not in aligned[1]:
#                 prefbias += numleadingsyms(aligned[0],'_') + numleadingsyms(aligned[1],'_')
#                 suffbias += numtrailingsyms(aligned[0],'_') + numtrailingsyms(aligned[1],'_')
#         for l in lines: # Read in lines and extract transformation rules from pairs
#             lemma, msd, form = l.split(u'\t')
#             if prefbias > suffbias:
#                 lemma = lemma[::-1]
#                 form = form[::-1]
#             prules, srules = prefix_suffix_rules_get(lemma, form)
#
#             if msd not in allprules and len(prules) > 0:
#                 allprules[msd] = {}
#             if msd not in allsrules and len(srules) > 0:
#                 allsrules[msd] = {}
#
#             for r in prules:
#                 if (r[0],r[1]) in allprules[msd]:
#                     allprules[msd][(r[0],r[1])] = allprules[msd][(r[0],r[1])] + 1
#                 else:
#                     allprules[msd][(r[0],r[1])] = 1
#
#             for r in srules:
#                 if (r[0],r[1]) in allsrules[msd]:
#                     allsrules[msd][(r[0],r[1])] = allsrules[msd][(r[0],r[1])] + 1
#                 else:
#                     allsrules[msd][(r[0],r[1])] = 1
#
#         # Run eval on dev
#         devlines = [line.strip() for line in open(path + lang + ".dev", "r", encoding='utf8') if line != '\n']
#         if TEST:
#             devlines = [line.strip() for line in open(path + lang + ".tst", "r", encoding='utf8') if line != '\n']
#         numcorrect = 0
#         numguesses = 0
#         if OUTPUT:
#             outfile = open(path + lang + ".out", "w", encoding='utf8')
#         for l in devlines:
#             lemma, msd, correct = l.split(u'\t')
# #                    lemma, msd, = l.split(u'\t')
#             if prefbias > suffbias:
#                 lemma = lemma[::-1]
#             outform = apply_best_rule(lemma, msd, allprules, allsrules)
#             if prefbias > suffbias:
#                 outform = outform[::-1]
#                 lemma = lemma[::-1]
#             if outform == correct:
#                 numcorrect += 1
#             numguesses += 1
#             if OUTPUT:
#                 outfile.write(lemma + "\t" + msd + "\t" + outform + "\n")
#
#         if OUTPUT:
#             outfile.close()
#
#         numlang += 1
#         totalavg += numcorrect/float(numguesses)
#
#         print(lang + ": " + str(str(numcorrect/float(numguesses)))[0:7])
#
#     print("Average accuracy", totalavg/float(numlang))
#
#
# if __name__ == "__main__":
#     main(sys.argv)

# %% [markdown]
# Looking over the code structure, we can see that it first defines a bunch of utility/helper functions at the top and then a **main** function at the bottom (starting at line 162).
#
# To understand the code structure, let's start by looking at the `main()` function.
#
# ## The `main()` function
#
# ### Running the module as a script vs. importing it
#
# At the very very end of the code (line 260), there is a little conditional expression that says:
#
# ```python
# if __name__ == "__main__":
#     main(sys.argv)
# ```
#
# This conditional expression makes the `nonneural.py` code ["usable as a script as well as an importable module"](https://docs.python.org/3/tutorial/modules.html#executing-modules-as-scripts).
#
# If we type
#
# ```bash
# # I am in the shell!
# python nonneural.net
# ```
#
# on the command line (e.g., in a bash shell), the `_name_` is set to `__main__` and the code in the conditional expression is run.
# But if we import the code as a module in a python interpreter using
#
# ```python
# # I am in a python interpreter
# import nonneural
# ```
#
# then the `main()` function is not run, but we get to access all the functions that were defined in the script.

# %% [markdown]
# ## Arguments for script, help, global variable initialization: lines 162-186
#
# The first section of the `main()` function is important if we are running `nonneural.py` as a script.
# It sets the options we have for including arguments when we run the script (note: the `-t` option doesn't actually work!)
# It also sets defaults for the variables `TEST`, `OUTPUT`, `HELP` and `path`.
#
# ```python
# def main(argv):
#     options, remainder = getopt.gnu_getopt(argv[1:], 'ohp:', ['output','help','path='])
#     TEST, OUTPUT, HELP, path = False,False, False, '../data/'
#     for opt, arg in options:
#         if opt in ('-o', '--output'):
#             OUTPUT = True
#         if opt in ('-t', '--test'):
#             TEST = True
#         if opt in ('-h', '--help'):
#             HELP = True
#         if opt in ('-p', '--path'):
#             path = arg
#
# ```
#
# So for instance, we can generate output files if we run the script with the `-o` argument
#
# ```bash
# # I am in the shell!
# python nonneural.net -o
# ```
#
#
# The next part (line 175-184) sets the message printed if we ask for help in the shell.
#
# ```python
#     if HELP:
#             print("\n*** Baseline for the SIGMORPHON 2020 shared task ***\n")
#             print("By default, the program runs all languages only evaluating accuracy.")
#             print("To create output files, use -o")
#             print("The training and dev-data are assumed to live in ./part1/development_languages/")
#             print("Options:")
#             print(" -o         create output files with guesses (and don't just evaluate)")
#             print(" -t         evaluate on test instead of dev")
#             print(" -p [path]  data files path. Default is ../data/")
#             quit()
#
# ```
#
# We can ask for help in the shell:
#
# ```bash
# # I am in the shell!
# python nonneural.net -h
# python nonneural.net --help
# ```
#
# If we are in a Python interpreter and ask for help, we get back the docstrings in the script.
#
# ```python
# # I am in a python interpreter
# import nonneural
# help(nonneural)
# ```

# %%
help(nonneural)
# Out:
# Help on module nonneural:
#
# NAME
#     nonneural
#
# DESCRIPTION
#     Non-neural baseline system for the SIGMORPHON 2020 Shared Task 0.
#     Author: Mans Hulden
#     Modified by: Tiago Pimentel
#     Modified by: Jordan Kodner
#     Modified by: Omer Goldman
#     Last Update: 22/03/2021
#
# FUNCTIONS
#     alignprs(lemma, form)
#         Break lemma/form into three parts:
#         IN:  1 | 2 | 3
#         OUT: 4 | 5 | 6
#         1/4 are assumed to be prefixes, 2/5 the stem, and 3/6 a suffix.
#         1/4 and 3/6 may be empty.
#
#     apply_best_rule(lemma, msd, allprules, allsrules)
#         Applies the longest-matching suffix-changing rule given an input
#         form and the MSD. Length ties in suffix rules are broken by frequency.
#         For prefix-changing rules, only the most frequent rule is chosen.
#
#     halign(s, t)
#         Align two strings by Hamming distance.
#
#     hamming(s, t)
#
#     levenshtein(s, t, inscost=1.0, delcost=1.0, substcost=1.0)
#         Recursive implementation of Levenshtein, with alignments returned.
#
#     main(argv)
#
#     memolrec(func)
#         Memoizer for Levenshtein.
#
#     numleadingsyms(s, symbol)
#
#     numtrailingsyms(s, symbol)
#
#     prefix_suffix_rules_get(lemma, form)
#         Extract a number of suffix-change and prefix-change rules
#         based on a given example lemma+inflected form.
#
# FILE
#     /Users/yzfu/Documents/2023-2026/2024Fall/LNG409/LINGUIST-409_Fall-2024/nonneural.py

# %% [markdown]
# Finally, line 186 initializes global variables `totalavg` and `numlang` to 0.0 and 0.
#
# ```python
#     totalavg, numlang = 0.0, 0
# ```

# %% [markdown]
# ## The giant for loop (lines 187-257)
#
# Line 187 starts a giant `for` loop that spans the rest of the `main()` function.
#
# ```python
#     for lang in [os.path.splitext(d)[0] for d in os.listdir(path) if '.trn' in d]:
# ```
# The loop iterates over each language `lang` in the `path` directory, if the language has a training data file (indicated by `.trn`)
#
# We can take a look at what the list comprehension in line 187 does:

# %%
# what needs to be added here?
path = 'data/'
[os.path.splitext(d)[0] for d in os.listdir(path) if '.trn' in d]
# Out:
# ['tur']

# %% [markdown]
# If we skim over the rest of the for loop we can look at the comments to get hints about what the code is supposed to do:
#
# 1. "test if language is predominantly suffixing or prefixing" (line 193)
# 2. "Read in lines and extract transformation rules from pairs" (line 202, kind of hidden)
# 3. "run eval on dev" (line 226)
#
# Let's first look at the rest of the beginning bit of the for loop, lines 187-191, before the test for suffixing/prefixing :
#
# ```python
# for lang in [os.path.splitext(d)[0] for d in os.listdir(path) if '.trn' in d]:
#         allprules, allsrules = {}, {}
#         if not os.path.isfile(path + lang +  ".trn"):
#             continue
#         lines = [line.strip() for line in open(path + lang + ".trn", "r", encoding='utf8') if line != '\n']
#
# ```
#
# What's going on in this part of the code?
# Can we take a look at what `lines` is?

# %%
# CODE BLOCK TO INSPECT lines
for lang in [os.path.splitext(d)[0] for d in os.listdir(path) if '.trn' in d]:
        allprules, allsrules = {}, {}
        if not os.path.isfile(path + lang +  ".trn"):
            continue
        lines = [line.strip() for line in open(path + lang + ".trn", "r", encoding='utf8') if line != '\n']
lines
# Out:
# ['Abu Dabili\tN;ABL(PL)\tAbu Dabililerden',
#  'Abu Dabili\tN;ABL(PL;PSS(2,PL))\tAbu Dabililerinizden',
#  'Abu Dabili\tN;ABL(PL;PSS(3,SG))\tAbu Dabililerinden',
#  'Abu Dabili\tN;ABL(SG;PSS(2,SG))\tAbu Dabilinden',
#  'Abu Dabili\tN;ACC(PL;PSS(1,PL))\tAbu Dabililerimizi',
#  'Abu Dabili\tN;ACC(PL;PSS(2,PL))\tAbu Dabililerinizi',
#  'Abu Dabili\tN;ACC(PL;PSS(2,SG))\tAbu Dabililerini',
#  'Abu Dabili\tN;ACC(PL;PSS(3,SG))\tAbu Dabililerini',
#  'Abu Dabili\tN;ACC(SG;PSS(2,PL))\tAbu Dabilinizi',
#  'Abu Dabili\tN;ACC(SG;PSS(2,SG))\tAbu Dabilini',
#  'Abu Dabili\tN;DAT(PL;PSS(2,SG))\tAbu Dabililerine',
#  'Abu Dabili\tN;GEN(PL;PSS(1,PL))\tAbu Dabililerimizin',
#  'Abu Dabili\tN;GEN(PL;PSS(2,PL))\tAbu Dabililerinizin',
#  'Abu Dabili\tN;GEN(PL;PSS(3,SG))\tAbu Dabililerinin',
#  'Abu Dabili\tN;GEN(SG;PSS(2,PL))\tAbu Dabilinizin',
#  'Abu Dabili\tN;LOC(PL)\tAbu Dabililerde',
#  'Abu Dabili\tN;LOC(PL;PSS(3,SG))\tAbu Dabililerinde',
#  'Abu Dabili\tN;LOC(SG;PSS(2,PL))\tAbu Dabilinizde',
#  'Abu Dabili\tN;LOC(SG;PSS(2,SG))\tAbu Dabilinde',
#  'Abu Dabili\tN;NOM(PL;PSS(2,PL))\tAbu Dabilileriniz',
#  'Abu Dabili\tN;PL;IND;PST;NOM(2,PL)\tAbu Dabililerdiniz',
#  'Abu Dabili\tN;PL;INFR;PST;NOM(2,SG)\tAbu Dabililermişsin',
#  'Abu Dabili\tN;PL;PRS;NOM(3,PL)\tAbu Dabililerdir',
#  'Abu Dabili\tN;PL;PRS;NOM(3,SG)\tAbu Dabililer',
#  'Abu Dabili\tN;SG;IND;PST;NOM(2,SG)\tAbu Dabiliydin',
#  'Abu Dabili\tN;SG;INFR;PST;NOM(1,SG)\tAbu Dabiliymişim',
#  'Abu Dabili\tN;SG;INFR;PST;NOM(2,SG)\tAbu Dabiliymişsin',
#  'Abu Dabili\tN;SG;PRS;NOM(2,PL)\tAbu Dabilisiniz',
#  'Belgratlı\tN;ABL(PL)\tBelgratlılardan',
#  'Belgratlı\tN;ABL(PL;PSS(2,PL))\tBelgratlılarınızdan',
#  'Belgratlı\tN;ACC(PL;PSS(2,SG))\tBelgratlılarını',
#  'Belgratlı\tN;ACC(PL;PSS(3,SG))\tBelgratlılarını',
#  'Belgratlı\tN;ACC(SG)\tBelgratlıyı',
#  'Belgratlı\tN;DAT(SG;PSS(2,SG))\tBelgratlına',
#  'Belgratlı\tN;DAT(SG;PSS(3,SG))\tBelgratlısına',
#  'Belgratlı\tN;GEN(PL)\tBelgratlıların',
#  'Belgratlı\tN;GEN(PL;PSS(2,SG))\tBelgratlılarının',
#  'Belgratlı\tN;GEN(PL;PSS(3,SG))\tBelgratlılarının',
#  'Belgratlı\tN;GEN(SG)\tBelgratlının',
#  'Belgratlı\tN;LOC(SG)\tBelgratlıda',
#  'Belgratlı\tN;NOM(SG;PSS(2,SG))\tBelgratlın',
#  'Belgratlı\tN;PL;IND;PST;NOM(2,PL)\tBelgratlılardınız',
#  'Belgratlı\tN;PL;IND;PST;NOM(2,SG)\tBelgratlılardın',
#  'Belgratlı\tN;PL;IND;PST;NOM(3,PL)\tBelgratlılardı',
#  'Belgratlı\tN;PL;IND;PST;NOM(3,SG)\tBelgratlılardı',
#  'Belgratlı\tN;PL;INFR;PST;NOM(2,PL)\tBelgratlılarmışsınız',
#  'Belgratlı\tN;PL;PRS;NOM(1,SG)\tBelgratlılarım',
#  'Belgratlı\tN;PL;PRS;NOM(2,PL)\tBelgratlılarsınız',
#  'Belgratlı\tN;PL;PRS;NOM(2,SG)\tBelgratlılarsın',
#  'Belgratlı\tN;PL;PRS;NOM(3,PL)\tBelgratlılardır',
#  'Belgratlı\tN;PL;PRS;NOM(3,SG)\tBelgratlılar',
#  'Belgratlı\tN;SG;IND;PST;NOM(1,SG)\tBelgratlıydım',
#  'Belgratlı\tN;SG;IND;PST;NOM(3,PL)\tBelgratlıydılar',
#  'Belgratlı\tN;SG;IND;PST;NOM(3,SG)\tBelgratlıydı',
#  'Belgratlı\tN;SG;INFR;PST;NOM(1,SG)\tBelgratlıymışım',
#  'Belgratlı\tN;SG;INFR;PST;NOM(2,SG)\tBelgratlıymışsın',
#  'Trabzon hurması\tN;ABL(PL)\tTrabzon hurmalarından',
#  'Trabzon hurması\tN;ABL(SG)\tTrabzon hurmasından',
#  'Trabzon hurması\tN;ACC(PL)\tTrabzon hurmalarını',
#  'Trabzon hurması\tN;ACC(SG)\tTrabzon hurmasını',
#  'Trabzon hurması\tN;DAT(PL)\tTrabzon hurmalarına',
#  'Trabzon hurması\tN;DAT(SG)\tTrabzon hurmasına',
#  'Trabzon hurması\tN;GEN(PL)\tTrabzon hurmalarının',
#  'Trabzon hurması\tN;GEN(SG)\tTrabzon hurmasının',
#  'Trabzon hurması\tN;LOC(PL)\tTrabzon hurmalarında',
#  'Trabzon hurması\tN;LOC(SG)\tTrabzon hurmasında',
#  'Trabzon hurması\tN;NOM(PL)\tTrabzon hurmaları',
#  'Trabzon hurması\tN;NOM(SG)\tTrabzon hurması',
#  "Yönetim Kurulu Başkanı\tN;ABL(PL)\tYönetim Kurulu Başkanları'ndan",
#  "Yönetim Kurulu Başkanı\tN;ABL(SG)\tYönetim Kurulu Başkanı'ndan",
#  "Yönetim Kurulu Başkanı\tN;ACC(PL)\tYönetim Kurulu Başkanları'nı",
#  "Yönetim Kurulu Başkanı\tN;ACC(SG)\tYönetim Kurulu Başkanı'nı",
#  "Yönetim Kurulu Başkanı\tN;DAT(PL)\tYönetim Kurulu Başkanları'na",
#  "Yönetim Kurulu Başkanı\tN;DAT(SG)\tYönetim Kurulu Başkanı'na",
#  "Yönetim Kurulu Başkanı\tN;GEN(PL)\tYönetim Kurulu Başkanları'nın",
#  "Yönetim Kurulu Başkanı\tN;GEN(SG)\tYönetim Kurulu Başkanı'nın",
#  "Yönetim Kurulu Başkanı\tN;LOC(PL)\tYönetim Kurulu Başkanları'nda",
#  "Yönetim Kurulu Başkanı\tN;LOC(SG)\tYönetim Kurulu Başkanı'nda",
#  'Yönetim Kurulu Başkanı\tN;NOM(PL)\tYönetim Kurulu Başkanları',
#  'Yönetim Kurulu Başkanı\tN;NOM(SG)\tYönetim Kurulu Başkanı',
#  'acıktırmak\tV;IND;FUT;PROG;NEG;DECL;NOM(1,PL)\tyaptırıyor olmayacağız',
#  'acıktırmak\tV;IND;FUT;PROG;NEG;INTR;NOM(3,SG)\tyaptırıyor olmayacak mı',
#  'acıktırmak\tV;IND;FUT;PROG;POS;DECL;NOM(1,PL)\tyaptırıyor olacağız',
#  'acıktırmak\tV;IND;PRS;HAB;NEG;DECL;NOM(3,SG)\tacıktırmaz',
#  'acıktırmak\tV;IND;PRS;PROG;NEG;INTR;NOM(3,PL)\tacıktırmıyorlar mı',
#  'acıktırmak\tV;IND;PST;NEG;DECL;NOM(2,SG)\tacıktırmadın',
#  'acıktırmak\tV;IND;PST;PERF;INTR;POS;NOM(3,PL)\tacıktırdılar mıydı',
#  'acıktırmak\tV;IND;PST;PERF;POS;DECL;NOM(2,PL)\tacıktırdıydınız',
#  'acıktırmak\tV;IND;PST;PROG;NEG;DECL;NOM(1,SG)\tacıktırmıyordum',
#  'acıktırmak\tV;IND;PST;PROG;NEG;INTR;NOM(1,SG)\tacıktırmıyor muydum',
#  'acıktırmak\tV;IND;PST;PROG;NEG;INTR;NOM(2,SG)\tacıktırmıyor muydun',
#  'acıktırmak\tV;IND;PST;PRSP;PROG;INTR;POS;NOM(2,PL)\tyaptırıyor olacak mıydınız',
#  'acıktırmak\tV;IND;PST;PRSP;PROG;NEG;DECL;NOM(2,SG)\tyaptırıyor olmayacaktın',
#  'acıktırmak\tV;IND;PST;PRSP;PROG;NEG;DECL;NOM(3,PL)\tyaptırıyor olmayacaklardı',
#  'acıktırmak\tV;INFR;FUT;HAB;INTR;POS;NOM(1,PL)\tyaptırır olacak mıymışız',
#  'acıktırmak\tV;INFR;FUT;HAB;INTR;POS;NOM(2,SG)\tyaptırır olacak mıymışsın',
#  'acıktırmak\tV;INFR;FUT;HAB;NEG;DECL;NOM(2,SG)\tyaptırır olmayacakmışsın',
#  'acıktırmak\tV;INFR;FUT;PERF;INTR;POS;NOM(2,PL)\tacıktırmış olacak mısınız',
#  'acıktırmak\tV;INFR;PRS;PROG;NEG;INTR;NOM(3,SG)\tacıktırmıyor muymuş',
#  'acıktırmak\tV;INFR;PST;NEG;DECL;NOM(3,PL)\tacıktırmamışlar',
#  'acıktırmak\tV;INFR;PST;PRSP;INTR;POS;NOM(3,PL)\tacıktırmış olacaklar mıydı',
#  'acıktırmak\tV;INFR;PST;SG;POS;DECL;NOM(2)\tacıktırmışmışsın',
#  'acıktırmak\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(3,SG)\tyaptırıyor olmalı mıymış',
#  'acıktırmak\tV;NEC;INFR;PST;NEG;DECL;NOM(2,SG)\tacıktırmamalıymışsın',
#  'acıktırmak\tV;NEC;PRS;POS;DECL;NOM(3,SG)\tacıktırmeli',
#  'acıktırmak\tV;NEC;PRS;PROG;INTR;POS;NOM(1,SG)\tyaptırıyor olmalı mıyım',
#  'acıktırmak\tV;NEC;PRS;PROG;POS;DECL;NOM(3,PL)\tyaptırıyor olmalılar',
#  'acıktırmak\tV;NEC;PST;INTR;POS;NOM(3,SG)\tacıktırmalı mıydı',
#  'acıtmak\tV;IND;FUT;PRSP;INTR;POS;NOM(2,PL)\tacıtacak olacak mısınız',
#  'acıtmak\tV;IND;FUT;PRSP;NEG;INTR;NOM(3,SG)\tacıtacak olmayacak mı',
#  'acıtmak\tV;IND;PRS;HAB;NEG;DECL;NOM(3,PL)\tacıtmazlar',
#  'acıtmak\tV;IND;PST;HAB;PROG;NEG;DECL;NOM(1,PL)\tacıtıyor olmazdık',
#  'acıtmak\tV;IND;PST;HAB;PROG;POS;DECL;NOM(2,SG)\tacıtıyor olurdun',
#  'acıtmak\tV;IND;PST;PERF;NEG;INTR;NOM(2,PL)\tacıtmadı mıydınız',
#  'acıtmak\tV;IND;PST;PERF;NEG;INTR;NOM(3,PL)\tacıtmadılar mıydı',
#  'acıtmak\tV;IND;PST;PROG;POS;DECL;NOM(1,PL)\tacıtıyorduk',
#  'acıtmak\tV;IND;PST;PRSP;POS;DECL;NOM(1,SG)\tacıtacaktım',
#  'acıtmak\tV;IND;PST;PRSP;PROG;NEG;INTR;NOM(1,PL)\tacıtıyor olmayacak mıydık',
#  'acıtmak\tV;INFR;FUT;NEG;DECL;NOM(2,PL)\tacıtmayacakmışsınız',
#  'acıtmak\tV;INFR;FUT;PERF;INTR;POS;NOM(3,PL)\tacıtmış olacaklar mı',
#  'acıtmak\tV;INFR;FUT;PRSP;INTR;POS;NOM(1,SG)\tacıtacak olacak mıymışım',
#  'acıtmak\tV;INFR;PRS;HAB;NEG;INTR;NOM(2,PL)\tacıtmaz mıymışsınız',
#  'acıtmak\tV;INFR;PRS;PROG;INTR;POS;NOM(1,PL)\tacıtıyor muymuşuz',
#  'acıtmak\tV;INFR;PRS;PROG;INTR;POS;NOM(3,PL)\tacıtıyorlar mıymış',
#  'acıtmak\tV;INFR;PRS;PROG;INTR;POS;NOM(3,SG)\tacıtıyor muymuş',
#  'acıtmak\tV;INFR;PRS;PROG;NEG;DECL;NOM(3,PL)\tacıtmıyorlarmış',
#  'acıtmak\tV;INFR;PST;PL;POS;DECL;NOM(3)\tacıtmışlarmış',
#  'acıtmak\tV;INFR;PST;PRSP;INTR;POS;NOM(3,SG)\tacıtmış olacak mıydı',
#  'acıtmak\tV;INFR;PST;PRSP;NEG;INTR;NOM(2,SG)\tacıtmış olmayacak mıydın',
#  'acıtmak\tV;INFR;PST;PRSP;POS;DECL;NOM(1,PL)\tacıtmış olacaktık',
#  'acıtmak\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(1,SG)\tacıtıyor olmalı mıymışım',
#  'acıtmak\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(3,PL)\tacıtıyor olmalılar mıymış',
#  'acıtmak\tV;NEC;INFR;PRS;PROG;POS;DECL;NOM(2,PL)\tacıtıyor olmalıymışsınız',
#  'acıtmak\tV;NEC;PRS;NEG;INTR;NOM(1,PL)\tacıtmameli miyiz',
#  'acıtmak\tV;NEC;PST;PROG;NEG;DECL;NOM(2,PL)\tacıtıyor olmamalıydınız',
#  'ahududu\tN;ABL(PL)\tahudutlarından',
#  'ahududu\tN;ABL(SG)\tahududundan',
#  'ahududu\tN;ACC(PL)\tahudutlarını',
#  'ahududu\tN;ACC(SG)\tahududunu',
#  'ahududu\tN;DAT(PL)\tahudutlarına',
#  'ahududu\tN;DAT(SG)\tahududuna',
#  'ahududu\tN;GEN(SG)\tahududunun',
#  'ahududu\tN;LOC(PL)\tahudutlarında',
#  'ahududu\tN;LOC(SG)\tahududunda',
#  'ahududu\tN;NOM(PL)\tahudutları',
#  'ahududu\tN;NOM(SG)\tahududu',
#  'albüm\tN;ABL(PL)\talbümlerden',
#  'albüm\tN;ABL(PL;PSS(1,PL))\talbümlerimizden',
#  'albüm\tN;ABL(PL;PSS(2,SG))\talbümlerinden',
#  'albüm\tN;ABL(PL;PSS(3,SG))\talbümlerinden',
#  'albüm\tN;ABL(SG;PSS(2,PL))\talbümünüzden',
#  'albüm\tN;ACC(PL;PSS(2,SG))\talbümlerini',
#  'albüm\tN;ACC(SG;PSS(1,PL))\talbümümüzü',
#  'albüm\tN;ACC(SG;PSS(2,SG))\talbümünü',
#  'albüm\tN;ACC(SG;PSS(3,SG))\talbümünü',
#  'albüm\tN;DAT(PL;PSS(2,PL))\talbümlerinize',
#  'albüm\tN;DAT(PL;PSS(3,SG))\talbümlerine',
#  'albüm\tN;DAT(SG)\talbüme',
#  'albüm\tN;GEN(PL)\talbümlerin',
#  'albüm\tN;GEN(PL;PSS(2,SG))\talbümlerinin',
#  'albüm\tN;GEN(SG;PSS(1,PL))\talbümümüzün',
#  'albüm\tN;LOC(PL)\talbümlerde',
#  'albüm\tN;LOC(PL;PSS(2,PL))\talbümlerinizde',
#  'albüm\tN;LOC(PL;PSS(2,SG))\talbümlerinde',
#  'albüm\tN;LOC(PL;PSS(3,SG))\talbümlerinde',
#  'albüm\tN;LOC(SG)\talbümde',
#  'albüm\tN;LOC(SG;PSS(1,PL))\talbümümüzde',
#  'albüm\tN;LOC(SG;PSS(2,PL))\talbümünüzde',
#  'albüm\tN;LOC(SG;PSS(3,SG))\talbümünde',
#  'albüm\tN;NOM(PL)\talbümler',
#  'albüm\tN;NOM(PL;PSS(2,SG))\talbümlerin',
#  'albüm\tN;NOM(SG;PSS(1,PL))\talbümümüz',
#  'albüm\tN;NOM(SG;PSS(2,PL))\talbümünüz',
#  'albüm\tN;NOM(SG;PSS(3,SG))\talbümü',
#  'alfa sürümü\tN;ABL(PL)\talfa sürümlerinden',
#  'alfa sürümü\tN;ABL(SG)\talfa sürümünden',
#  'alfa sürümü\tN;ACC(PL)\talfa sürümlerini',
#  'alfa sürümü\tN;ACC(SG)\talfa sürümünu',
#  'alfa sürümü\tN;DAT(PL)\talfa sürümlerine',
#  'alfa sürümü\tN;DAT(SG)\talfa sürümüne',
#  'alfa sürümü\tN;GEN(PL)\talfa sürümlerinin',
#  'alfa sürümü\tN;GEN(SG)\talfa sürümünün',
#  'alfa sürümü\tN;LOC(PL)\talfa sürümlerinde',
#  'alfa sürümü\tN;LOC(SG)\talfa sürümünde',
#  'alfa sürümü\tN;NOM(PL)\talfa sürümleri',
#  'alfa sürümü\tN;NOM(SG)\talfa sürümü',
#  'almak\tV;IMP;LGSPEC2;POS;DECL;NOM(2,PL)\talınız',
#  'almak\tV;IND;FUT;NEG;INTR;NOM(1,SG)\talmayacak mıyım',
#  'almak\tV;IND;FUT;NEG;INTR;NOM(3,SG)\talmayacak mı',
#  'almak\tV;IND;FUT;PROG;POS;DECL;NOM(1,SG)\talıyor olacağım',
#  'almak\tV;IND;FUT;PRSP;INTR;POS;NOM(3,PL)\talacak olacaklar mı',
#  'almak\tV;IND;PRS;PROG;NEG;DECL;NOM(2,SG)\talmıyorsun',
#  'almak\tV;IND;PRS;PROG;POS;DECL;NOM(1,PL)\talıyoruz',
#  'almak\tV;IND;PST;HAB;PROG;POS;DECL;NOM(3,PL)\talıyor olurlardı',
#  'almak\tV;IND;PST;INTR;POS;NOM(1,SG)\taldım mı',
#  'almak\tV;IND;PST;PRSP;INTR;POS;NOM(1,PL)\talacak mıydık',
#  'almak\tV;IND;PST;PRSP;NEG;INTR;NOM(1,SG)\talmayacak mıydım',
#  'almak\tV;IND;PST;PRSP;PROG;NEG;INTR;NOM(1,SG)\talıyor olmayacak mıydım',
#  'almak\tV;INFR;FUT;NEG;DECL;NOM(2,PL)\talmayacakmışsınız',
#  'almak\tV;INFR;FUT;PERF;NEG;INTR;NOM(2,SG)\talmış olmayacak mısın',
#  'almak\tV;INFR;FUT;PROG;INTR;POS;NOM(2,SG)\talıyor olacak mıymışsın',
#  'almak\tV;INFR;FUT;PRSP;NEG;INTR;NOM(3,SG)\talacak olmayacak mıymış',
#  'almak\tV;INFR;FUT;PRSP;POS;DECL;NOM(1,SG)\talacak olacakmışım',
#  'almak\tV;INFR;PRS;HAB;POS;DECL;NOM(3,PL)\talırlarmış',
#  'almak\tV;INFR;PRS;PROG;NEG;DECL;NOM(3,PL)\talmıyorlarmış',
#  'almak\tV;INFR;PST;NEG;INTR;NOM(1,SG)\talmamış mıyım',
#  'almak\tV;INFR;PST;PL;NEG;INTR;NOM(2)\talmamış mıymışsınız',
#  'almak\tV;INFR;PST;POS;DECL;NOM(2,SG)\talmışsın',
#  'almak\tV;INFR;PST;PRSP;NEG;DECL;NOM(2,SG)\talmış olmayacaktın',
#  'almak\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(3,PL)\talıyor olmalılar mıymış',
#  'almak\tV;NEC;INFR;PRS;PROG;NEG;DECL;NOM(2,SG)\talıyor olmamalıymışsın',
#  'almak\tV;NEC;INFR;PST;NEG;DECL;NOM(2,SG)\talmamalıymışsın',
#  'almak\tV;NEC;PST;PROG;NEG;DECL;NOM(3,PL)\talıyor olmamalılardı',
#  'altdizin\tN;ABL(PL)\taltdizinlerden',
#  'altdizin\tN;ABL(SG)\taltdizinden',
#  'altdizin\tN;ACC(PL)\taltdizinleri',
#  'altdizin\tN;ACC(SG)\taltdizini',
#  'altdizin\tN;DAT(PL)\taltdizinlere',
#  'altdizin\tN;DAT(SG)\taltdizine',
#  'altdizin\tN;GEN(PL)\taltdizinlerin',
#  'altdizin\tN;GEN(SG)\taltdizinin',
#  'altdizin\tN;LOC(PL)\taltdizinlerde',
#  'altdizin\tN;LOC(SG)\taltdizinde',
#  'altdizin\tN;NOM(PL)\taltdizinler',
#  'altdizin\tN;NOM(SG)\taltdizin',
#  'altın\tN;ABL(PL)\taltınlardan',
#  'altın\tN;ABL(PL;PSS(2,PL))\taltınlarınızdan',
#  'altın\tN;ABL(PL;PSS(3,SG))\taltınlarından',
#  'altın\tN;ABL(SG)\taltından',
#  'altın\tN;ABL(SG;PSS(1,PL))\taltınımızdan',
#  'altın\tN;ABL(SG;PSS(2,PL))\taltınınızdan',
#  'altın\tN;ABL(SG;PSS(3,SG))\taltınından',
#  'altın\tN;ACC(PL)\taltınları',
#  'altın\tN;ACC(PL;PSS(1,PL))\taltınlarımızı',
#  'altın\tN;ACC(PL;PSS(2,PL))\taltınlarınızı',
#  'altın\tN;ACC(PL;PSS(2,SG))\taltınlarını',
#  'altın\tN;ACC(SG;PSS(2,PL))\taltınınızı',
#  'altın\tN;DAT(PL)\taltınlara',
#  'altın\tN;DAT(PL;PSS(2,SG))\taltınlarına',
#  'altın\tN;DAT(PL;PSS(3,SG))\taltınlarına',
#  'altın\tN;DAT(SG;PSS(2,SG))\taltınına',
#  'altın\tN;DAT(SG;PSS(3,SG))\taltınına',
#  'altın\tN;GEN(PL;PSS(2,PL))\taltınlarınızın',
#  'altın\tN;GEN(PL;PSS(2,SG))\taltınlarının',
#  'altın\tN;GEN(SG;PSS(3,SG))\taltınının',
#  'altın\tN;LOC(PL)\taltınlarda',
#  'altın\tN;LOC(PL;PSS(2,PL))\taltınlarınızda',
#  'altın\tN;LOC(SG;PSS(1,PL))\taltınımızda',
#  'altın\tN;LOC(SG;PSS(3,SG))\taltınında',
#  'altın\tN;NOM(PL;PSS(1,PL))\taltınlarımız',
#  'altın\tN;NOM(PL;PSS(2,PL))\taltınlarınız',
#  'altın\tN;NOM(PL;PSS(3,SG))\taltınları',
#  'alındırtmak\tV;IND;FUT;NEG;INTR;NOM(3,PL)\talındırtmayacaklar mı',
#  'alındırtmak\tV;IND;FUT;POS;DECL;NOM(3,PL)\talındırtacaklar',
#  'alındırtmak\tV;IND;PRS;HAB;INTR;POS;NOM(2,PL)\talındırtır mısınız',
#  'alındırtmak\tV;IND;PRS;HAB;NEG;DECL;NOM(2,SG)\talındırtmazsın',
#  'alındırtmak\tV;IND;PST;HAB;NEG;DECL;NOM(3,SG)\talındırtmazdı',
#  'alındırtmak\tV;IND;PST;HAB;NEG;INTR;NOM(1,SG)\talındırtmaz mıydım',
#  'alındırtmak\tV;IND;PST;HAB;PROG;POS;DECL;NOM(1,PL)\talındırtıyor olurduk',
#  'alındırtmak\tV;IND;PST;NEG;DECL;NOM(1,SG)\talındırtmadım',
#  'alındırtmak\tV;IND;PST;PRSP;POS;DECL;NOM(3,PL)\talındırtacaklardı',
#  'alındırtmak\tV;IND;PST;PRSP;PROG;POS;DECL;NOM(2,SG)\talındırtıyor olacaktın',
#  'alındırtmak\tV;INFR;FUT;HAB;INTR;POS;NOM(3,SG)\talındırtır olacak mıymış',
#  'alındırtmak\tV;INFR;FUT;HAB;POS;DECL;NOM(2,PL)\talındırtır olacakmışsınız',
#  'alındırtmak\tV;INFR;FUT;NEG;INTR;NOM(3,SG)\talındırtmayacak mıymış',
#  'alındırtmak\tV;INFR;FUT;PROG;INTR;POS;NOM(1,PL)\talındırtıyor olacak mıymışız',
#  'alındırtmak\tV;INFR;FUT;PRSP;NEG;INTR;NOM(3,SG)\talındırtacak olmayacak mıymış',
#  'alındırtmak\tV;INFR;PRS;HAB;INTR;POS;NOM(2,PL)\talındırtır mıymışsınız',
#  'alındırtmak\tV;INFR;PST;PERF;INTR;POS;NOM(2,PL)\talındırtmış mıydınız',
#  'alındırtmak\tV;INFR;PST;PERF;NEG;INTR;NOM(3,PL)\talındırtmamışlar mıydı',
#  'alındırtmak\tV;INFR;PST;PL;INTR;POS;NOM(2)\talındırtmış mıymışsınız',
#  'alındırtmak\tV;INFR;PST;POS;DECL;NOM(2,PL)\talındırtmışsınız',
#  'alındırtmak\tV;INFR;PST;PRSP;NEG;DECL;NOM(2,SG)\talındırtmış olmayacaktın',
#  'alındırtmak\tV;NEC;INFR;PRS;PROG;NEG;DECL;NOM(2,SG)\talındırtıyor olmamalıymışsın',
#  'alındırtmak\tV;NEC;PRS;NEG;INTR;NOM(2,SG)\talındırtmameli misin',
#  'alındırtmak\tV;NEC;PRS;POS;DECL;NOM(2,PL)\talındırtmelisiniz',
#  'alındırtmak\tV;NEC;PRS;POS;DECL;NOM(3,SG)\talındırtmeli',
#  'alındırtmak\tV;NEC;PST;NEG;DECL;NOM(3,PL)\talındırtmamalılardı',
#  'alındırtmak\tV;NEC;PST;NEG;INTR;NOM(3,PL)\talındırtmamalılar mıydı',
#  'alındırtmak\tV;NEC;PST;PROG;NEG;DECL;NOM(1,PL)\talındırtıyor olmamalıydık',
#  'anahtar kelime\tN;ABL(PL;PSS(1,PL))\tanahtar kelimelerimizden',
#  'anahtar kelime\tN;ABL(PL;PSS(2,PL))\tanahtar kelimelerinizden',
#  'anahtar kelime\tN;ABL(PL;PSS(2,SG))\tanahtar kelimelerinden',
#  'anahtar kelime\tN;ABL(PL;PSS(3,SG))\tanahtar kelimelerinden',
#  'anahtar kelime\tN;ABL(SG)\tanahtar kelimeden',
#  'anahtar kelime\tN;ABL(SG;PSS(1,PL))\tanahtar kelimemizden',
#  'anahtar kelime\tN;ABL(SG;PSS(2,PL))\tanahtar kelimenizden',
#  'anahtar kelime\tN;ABL(SG;PSS(2,SG))\tanahtar kelimenden',
#  'anahtar kelime\tN;ABL(SG;PSS(3,SG))\tanahtar kelimesinden',
#  'anahtar kelime\tN;ACC(PL)\tanahtar kelimeleri',
#  'anahtar kelime\tN;ACC(PL;PSS(2,PL))\tanahtar kelimelerinizi',
#  'anahtar kelime\tN;ACC(SG;PSS(2,PL))\tanahtar kelimenizi',
#  'anahtar kelime\tN;DAT(PL)\tanahtar kelimelere',
#  'anahtar kelime\tN;DAT(SG;PSS(2,PL))\tanahtar kelimenize',
#  'anahtar kelime\tN;GEN(PL)\tanahtar kelimelerin',
#  'anahtar kelime\tN;GEN(PL;PSS(2,PL))\tanahtar kelimelerinizin',
#  'anahtar kelime\tN;GEN(PL;PSS(3,SG))\tanahtar kelimelerinin',
#  'anahtar kelime\tN;GEN(SG;PSS(2,PL))\tanahtar kelimenizin',
#  'anahtar kelime\tN;GEN(SG;PSS(2,SG))\tanahtar kelimenin',
#  'anahtar kelime\tN;GEN(SG;PSS(3,SG))\tanahtar kelimesinin',
#  'anahtar kelime\tN;LOC(PL)\tanahtar kelimelerde',
#  'anahtar kelime\tN;LOC(SG)\tanahtar kelimede',
#  'anahtar kelime\tN;LOC(SG;PSS(2,SG))\tanahtar kelimende',
#  'anahtar kelime\tN;LOC(SG;PSS(3,SG))\tanahtar kelimesinde',
#  'anahtar kelime\tN;NOM(PL;PSS(1,PL))\tanahtar kelimelerimiz',
#  'anahtar kelime\tN;NOM(PL;PSS(2,SG))\tanahtar kelimelerin',
#  'anahtar kelime\tN;NOM(SG;PSS(1,PL))\tanahtar kelimemiz',
#  'anahtar kelime\tN;NOM(SG;PSS(2,PL))\tanahtar kelimeniz',
#  'antropoloji\tN;ABL(PL)\tantropolojilerden',
#  'antropoloji\tN;ABL(SG)\tantropolojiden',
#  'antropoloji\tN;ACC(PL)\tantropolojileri',
#  'antropoloji\tN;ACC(SG)\tantropolojiyi',
#  'antropoloji\tN;DAT(PL)\tantropolojilere',
#  'antropoloji\tN;DAT(SG)\tantropolojiye',
#  'antropoloji\tN;GEN(PL)\tantropolojilerin',
#  'antropoloji\tN;GEN(SG)\tantropolojinin',
#  'antropoloji\tN;LOC(PL)\tantropolojilerde',
#  'antropoloji\tN;LOC(SG)\tantropolojide',
#  'antropoloji\tN;NOM(PL)\tantropolojiler',
#  'antropoloji\tN;NOM(SG)\tantropoloji',
#  'artmak\tV;IND;FUT;NEG;DECL;NOM(2,SG)\tartmayacaksın',
#  'artmak\tV;IND;FUT;PRSP;NEG;DECL;NOM(3,PL)\tartacak olmayacaklar',
#  'artmak\tV;IND;FUT;PRSP;NEG;INTR;NOM(1,PL)\tartacak olmayacak mıyız',
#  'artmak\tV;IND;PRS;HAB;NEG;DECL;NOM(2,SG)\tartmazsın',
#  'artmak\tV;IND;PRS;PROG;NEG;INTR;NOM(2,SG)\tartmıyor musun',
#  'artmak\tV;IND;PST;HAB;POS;DECL;NOM(1,SG)\tartardım',
#  'artmak\tV;IND;PST;HAB;PROG;NEG;DECL;NOM(1,PL)\tartıyor olmazdık',
#  'artmak\tV;IND;PST;HAB;PROG;POS;DECL;NOM(3,SG)\tartıyor olurdu',
#  'artmak\tV;IND;PST;INTR;POS;NOM(1,SG)\tarttım mı',
#  'artmak\tV;IND;PST;PERF;INTR;POS;NOM(1,PL)\tarttı mıydık',
#  'artmak\tV;IND;PST;PRSP;NEG;DECL;NOM(1,PL)\tartmayacaktık',
#  'artmak\tV;IND;PST;PRSP;PROG;POS;DECL;NOM(3,PL)\tartıyor olacaklardı',
#  'artmak\tV;INFR;FUT;INTR;POS;NOM(2,PL)\tartacak mıymışsınız',
#  'artmak\tV;INFR;FUT;NEG;DECL;NOM(3,SG)\tartmayacakmış',
#  'artmak\tV;INFR;FUT;PERF;NEG;INTR;NOM(1,PL)\tartmış olmayacak mıyız',
#  'artmak\tV;INFR;FUT;PROG;INTR;POS;NOM(1,PL)\tartıyor olacak mıymışız',
#  'artmak\tV;INFR;FUT;PRSP;NEG;DECL;NOM(1,SG)\tartacak olmayacakmışım',
#  'artmak\tV;INFR;FUT;PRSP;NEG;INTR;NOM(3,SG)\tartacak olmayacak mıymış',
#  'artmak\tV;INFR;PRS;HAB;NEG;INTR;NOM(1,SG)\tartmaz mıymışım',
#  'artmak\tV;INFR;PST;PERF;INTR;POS;NOM(2,SG)\tartmış mıydın',
#  'artmak\tV;INFR;PST;PERF;NEG;DECL;NOM(1,SG)\tartmamıştım',
#  'artmak\tV;INFR;PST;PL;NEG;DECL;NOM(2)\tartmamışmışsınız',
#  'artmak\tV;INFR;PST;PL;POS;DECL;NOM(3)\tartmışlarmış',
#  'artmak\tV;INFR;PST;PRSP;POS;DECL;NOM(3,PL)\tartmış olacaklardı',
#  'artmak\tV;INFR;PST;SG;INTR;POS;NOM(3)\tartmış mıymış',
#  'artmak\tV;NEC;PRS;PROG;INTR;POS;NOM(2,SG)\tartıyor olmalı mısın',
#  'artmak\tV;NEC;PRS;PROG;NEG;INTR;NOM(1,PL)\tartıyor olmamalı mıyız',
#  'artmak\tV;NEC;PST;INTR;POS;NOM(3,SG)\tartmalı mıydı',
#  'atom\tN;ABL(PL;PSS(1,PL))\tatomlarımızdan',
#  'atom\tN;ABL(PL;PSS(2,SG))\tatomlarından',
#  'atom\tN;ABL(PL;PSS(3,SG))\tatomlarından',
#  'atom\tN;ABL(SG)\tatomdan',
#  'atom\tN;ABL(SG;PSS(3,SG))\tatomundan',
#  'atom\tN;ACC(PL;PSS(1,PL))\tatomlarımızı',
#  'atom\tN;ACC(PL;PSS(3,SG))\tatomlarını',
#  'atom\tN;ACC(SG;PSS(3,SG))\tatomunu',
#  'atom\tN;DAT(PL;PSS(2,SG))\tatomlarına',
#  'atom\tN;DAT(SG;PSS(1,PL))\tatomumuza',
#  'atom\tN;DAT(SG;PSS(2,PL))\tatomunuza',
#  'atom\tN;DAT(SG;PSS(3,SG))\tatomuna',
#  'atom\tN;GEN(PL;PSS(1,PL))\tatomlarımızın',
#  'atom\tN;GEN(PL;PSS(2,PL))\tatomlarınızın',
#  'atom\tN;GEN(PL;PSS(3,SG))\tatomlarının',
#  'atom\tN;GEN(SG)\tatomun',
#  'atom\tN;GEN(SG;PSS(1,PL))\tatomumuzun',
#  'atom\tN;GEN(SG;PSS(2,SG))\tatomunun',
#  'atom\tN;LOC(PL)\tatomlarda',
#  'atom\tN;LOC(PL;PSS(2,SG))\tatomlarında',
#  'atom\tN;LOC(PL;PSS(3,SG))\tatomlarında',
#  'atom\tN;NOM(PL)\tatomlar',
#  'atom\tN;NOM(PL;PSS(1,PL))\tatomlarımız',
#  'atom\tN;NOM(PL;PSS(2,PL))\tatomlarınız',
#  'atom\tN;NOM(PL;PSS(3,SG))\tatomları',
#  'atom\tN;NOM(SG)\tatom',
#  'atom\tN;NOM(SG;PSS(1,PL))\tatomumuz',
#  'atom\tN;NOM(SG;PSS(3,SG))\tatomu',
#  'attırmak\tV;IND;PRS;PROG;NEG;INTR;NOM(1,SG)\tattırmıyor muyum',
#  'attırmak\tV;IND;PST;HAB;NEG;DECL;NOM(3,PL)\tattırmazlardı',
#  'attırmak\tV;IND;PST;HAB;PROG;INTR;POS;NOM(1,SG)\tatırıyor olur muydum',
#  'attırmak\tV;IND;PST;HAB;PROG;NEG;INTR;NOM(3,PL)\tatırıyor olmazlar mıydı',
#  'attırmak\tV;IND;PST;PERF;INTR;POS;NOM(3,SG)\tattırdı mıydı',
#  'attırmak\tV;IND;PST;PROG;INTR;POS;NOM(1,SG)\tatırıyor muydum',
#  'attırmak\tV;IND;PST;PROG;NEG;INTR;NOM(1,PL)\tattırmıyor muyduk',
#  'attırmak\tV;IND;PST;PRSP;NEG;INTR;NOM(3,PL)\tattırmayacaklar mıydı',
#  'attırmak\tV;IND;PST;PRSP;PROG;INTR;POS;NOM(1,PL)\tatırıyor olacak mıydık',
#  'attırmak\tV;INFR;FUT;HAB;NEG;DECL;NOM(2,SG)\tatırır olmayacakmışsın',
#  'attırmak\tV;INFR;FUT;HAB;POS;DECL;NOM(2,PL)\tatırır olacakmışsınız',
#  'attırmak\tV;INFR;FUT;NEG;DECL;NOM(1,PL)\tattırmayacakmışız',
#  'attırmak\tV;INFR;FUT;PERF;NEG;DECL;NOM(3,PL)\tattırmış olmayacaklar',
#  'attırmak\tV;INFR;FUT;PRSP;INTR;POS;NOM(3,SG)\tatıracak olacak mıymış',
#  'attırmak\tV;INFR;PRS;PROG;NEG;DECL;NOM(3,PL)\tattırmıyorlarmış',
#  'attırmak\tV;INFR;PRS;PROG;NEG;INTR;NOM(1,SG)\tattırmıyor muymuşum',
#  'attırmak\tV;INFR;PST;PRSP;INTR;POS;NOM(3,PL)\tattırmış olacaklar mıydı',
#  'attırmak\tV;INFR;PST;PRSP;POS;DECL;NOM(3,SG)\tattırmış olacaktı',
#  'attırmak\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(2,PL)\tatırıyor olmalı mıymışsınız',
#  'attırmak\tV;NEC;INFR;PRS;PROG;NEG;INTR;NOM(2,PL)\tatırıyor olmamalı mıymışsınız',
#  'attırmak\tV;NEC;INFR;PST;NEG;INTR;NOM(3,PL)\tattırmamalılar mıymış',
#  'attırmak\tV;NEC;INFR;PST;POS;DECL;NOM(1,SG)\tattırmalıymışım',
#  'attırmak\tV;NEC;PRS;INTR;POS;NOM(2,SG)\tattırmeli misin',
#  'attırmak\tV;NEC;PRS;NEG;INTR;NOM(3,SG)\tattırmameli mi',
#  'attırmak\tV;NEC;PRS;POS;DECL;NOM(2,SG)\tattırmelisin',
#  'attırmak\tV;NEC;PRS;PROG;NEG;INTR;NOM(2,SG)\tatırıyor olmamalı mısın',
#  'av\tN;ABL(PL)\tavlardan',
#  'av\tN;ABL(PL;PSS(3,SG))\tavlarından',
#  'av\tN;ABL(SG;PSS(1,PL))\tavımızdan',
#  'av\tN;ACC(PL;PSS(1,PL))\tavlarımızı',
#  'av\tN;ACC(PL;PSS(2,PL))\tavlarınızı',
#  'av\tN;ACC(SG;PSS(3,SG))\tavını',
#  'av\tN;DAT(PL;PSS(3,SG))\tavlarına',
#  'av\tN;DAT(SG;PSS(2,PL))\tavınıza',
#  'av\tN;DAT(SG;PSS(3,SG))\tavına',
#  'av\tN;GEN(PL)\tavların',
#  'av\tN;GEN(PL;PSS(2,PL))\tavlarınızın',
#  'av\tN;GEN(SG)\tavın',
#  'av\tN;GEN(SG;PSS(2,PL))\tavınızın',
#  'av\tN;LOC(PL;PSS(3,SG))\tavlarında',
#  'av\tN;LOC(SG;PSS(2,PL))\tavınızda',
#  'av\tN;NOM(PL)\tavlar',
#  'av\tN;NOM(PL;PSS(2,PL))\tavlarınız',
#  'av\tN;NOM(PL;PSS(3,SG))\tavları',
#  'av\tN;NOM(SG;PSS(2,SG))\tavın',
#  'av\tN;PL;IND;PST;NOM(3,PL)\tavlardı',
#  'av\tN;PL;INFR;PST;NOM(3,PL)\tavlarmış',
#  'av\tN;PL;PRS;NOM(1,PL)\tavlarız',
#  'av\tN;PL;PRS;NOM(2,PL)\tavlarsınız',
#  'av\tN;PL;PRS;NOM(3,PL)\tavlardır',
#  'av\tN;PL;PRS;NOM(3,SG)\tavlar',
#  'av\tN;SG;IND;PST;NOM(1,SG)\tavdım',
#  'av\tN;SG;IND;PST;NOM(3,SG)\tavdı',
#  'av\tN;SG;INFR;PST;NOM(2,PL)\tavmışsınız',
#  'avukat\tN;ABL(SG)\tavukattan',
#  'avukat\tN;ABL(SG;PSS(3,SG))\tavukatından',
#  'avukat\tN;ACC(PL;PSS(1,PL))\tavukatlarımızı',
#  'avukat\tN;ACC(PL;PSS(2,PL))\tavukatlarınızı',
#  'avukat\tN;ACC(PL;PSS(2,SG))\tavukatlarını',
#  'avukat\tN;ACC(SG)\tavukatı',
#  'avukat\tN;ACC(SG;PSS(2,PL))\tavukatınızı',
#  'avukat\tN;DAT(SG;PSS(2,PL))\tavukatınıza',
#  'avukat\tN;DAT(SG;PSS(2,SG))\tavukatına',
#  'avukat\tN;DAT(SG;PSS(3,SG))\tavukatına',
#  'avukat\tN;LOC(PL;PSS(1,PL))\tavukatlarımızda',
#  'avukat\tN;LOC(PL;PSS(2,PL))\tavukatlarınızda',
#  'avukat\tN;LOC(SG;PSS(3,SG))\tavukatında',
#  'avukat\tN;NOM(PL)\tavukatlar',
#  'avukat\tN;NOM(PL;PSS(2,PL))\tavukatlarınız',
#  'avukat\tN;NOM(PL;PSS(3,SG))\tavukatları',
#  'avukat\tN;NOM(SG;PSS(3,SG))\tavukatı',
#  'avukat\tN;PL;IND;PST;NOM(1,PL)\tavukatlardık',
#  'avukat\tN;PL;IND;PST;NOM(2,PL)\tavukatlardınız',
#  'avukat\tN;PL;IND;PST;NOM(3,PL)\tavukatlardı',
#  'avukat\tN;PL;PRS;NOM(1,PL)\tavukatlarız',
#  'avukat\tN;PL;PRS;NOM(2,PL)\tavukatlarsınız',
#  'avukat\tN;SG;IND;PST;NOM(1,SG)\tavukattım',
#  'avukat\tN;SG;IND;PST;NOM(3,SG)\tavukattı',
#  'avukat\tN;SG;INFR;PST;NOM(2,SG)\tavukatmışsın',
#  'avukat\tN;SG;INFR;PST;NOM(3,PL)\tavukatmışlar',
#  'avukat\tN;SG;INFR;PST;NOM(3,SG)\tavukatmış',
#  'avukat\tN;SG;PRS;NOM(1,PL)\tavukatız',
#  'ayna\tN;ABL(PL;PSS(1,PL))\taynalarımızdan',
#  'ayna\tN;ABL(PL;PSS(2,PL))\taynalarınızdan',
#  'ayna\tN;ABL(PL;PSS(2,SG))\taynalarından',
#  'ayna\tN;ABL(PL;PSS(3,SG))\taynalarından',
#  'ayna\tN;ABL(SG;PSS(1,PL))\taynamızdan',
#  'ayna\tN;ABL(SG;PSS(2,PL))\taynanızdan',
#  'ayna\tN;ABL(SG;PSS(2,SG))\taynandan',
#  'ayna\tN;ABL(SG;PSS(3,SG))\taynasından',
#  'ayna\tN;ACC(PL;PSS(1,PL))\taynalarımızı',
#  'ayna\tN;ACC(PL;PSS(2,PL))\taynalarınızı',
#  'ayna\tN;ACC(SG)\taynayı',
#  'ayna\tN;ACC(SG;PSS(3,SG))\taynasını',
#  'ayna\tN;DAT(PL;PSS(2,SG))\taynalarına',
#  'ayna\tN;DAT(PL;PSS(3,SG))\taynalarına',
#  'ayna\tN;DAT(SG)\taynaya',
#  'ayna\tN;GEN(PL;PSS(3,SG))\taynalarının',
#  'ayna\tN;GEN(SG)\taynanın',
#  'ayna\tN;GEN(SG;PSS(1,PL))\taynamızın',
#  'ayna\tN;GEN(SG;PSS(2,SG))\taynanın',
#  'ayna\tN;LOC(PL;PSS(1,PL))\taynalarımızda',
#  'ayna\tN;LOC(PL;PSS(2,SG))\taynalarında',
#  'ayna\tN;LOC(SG)\taynada',
#  'ayna\tN;LOC(SG;PSS(1,PL))\taynamızda',
#  'ayna\tN;LOC(SG;PSS(2,SG))\taynanda',
#  'ayna\tN;NOM(PL;PSS(1,PL))\taynalarımız',
#  'ayna\tN;NOM(PL;PSS(2,PL))\taynalarınız',
#  'ayna\tN;NOM(PL;PSS(3,SG))\taynaları',
#  'ayna\tN;NOM(SG;PSS(1,PL))\taynamız',
#  'ayrılma\tN;ABL(PL)\tayrılmalardan',
#  'ayrılma\tN;ABL(SG)\tayrılmadan',
#  'ayrılma\tN;ACC(PL)\tayrılmaları',
#  'ayrılma\tN;ACC(SG)\tayrılmayı',
#  'ayrılma\tN;DAT(PL)\tayrılmalara',
#  'ayrılma\tN;DAT(SG)\tayrılmaya',
#  'ayrılma\tN;GEN(PL)\tayrılmaların',
#  'ayrılma\tN;GEN(SG)\tayrılmanın',
#  'ayrılma\tN;LOC(PL)\tayrılmalarda',
#  'ayrılma\tN;LOC(SG)\tayrılmada',
#  'ayrılma\tN;NOM(PL)\tayrılmalar',
#  'ayrılma\tN;NOM(SG)\tayrılma',
#  'ayrılmak\tV;IMP;LGSPEC2;NEG;DECL;NOM(2,PL)\tayrılmayınız',
#  'ayrılmak\tV;IND;FUT;POS;DECL;NOM(1,SG)\tayrılacağım',
#  'ayrılmak\tV;IND;FUT;PROG;NEG;DECL;NOM(1,PL)\tayrılıyor olmayacağız',
#  'ayrılmak\tV;IND;FUT;PROG;NEG;DECL;NOM(1,SG)\tayrılıyor olmayacağım',
#  'ayrılmak\tV;IND;PRS;HAB;NEG;DECL;NOM(1,SG)\tayrılmam',
#  'ayrılmak\tV;IND;PRS;PROG;NEG;DECL;NOM(1,SG)\tayrılmıyorum',
#  'ayrılmak\tV;IND;PST;INTR;POS;NOM(1,PL)\tayrıldık mı',
#  'ayrılmak\tV;IND;PST;PERF;NEG;DECL;NOM(1,PL)\tayrılmadıydık',
#  'ayrılmak\tV;IND;PST;PERF;POS;DECL;NOM(2,SG)\tayrıldıydın',
#  'ayrılmak\tV;IND;PST;PROG;POS;DECL;NOM(2,PL)\tayrılıyordunuz',
#  'ayrılmak\tV;IND;PST;PRSP;INTR;POS;NOM(1,PL)\tayrılacak mıydık',
#  'ayrılmak\tV;INFR;FUT;HAB;NEG;INTR;NOM(3,SG)\tayrılır olmayacak mıymış',
#  'ayrılmak\tV;INFR;FUT;INTR;POS;NOM(3,PL)\tayrılacaklar mıymış',
#  'ayrılmak\tV;INFR;FUT;NEG;DECL;NOM(3,PL)\tayrılmayacaklarmış',
#  'ayrılmak\tV;INFR;FUT;POS;DECL;NOM(1,SG)\tayrılacakmışım',
#  'ayrılmak\tV;INFR;FUT;PROG;INTR;POS;NOM(3,PL)\tayrılıyor olacaklar mıymış',
#  'ayrılmak\tV;INFR;FUT;PROG;NEG;DECL;NOM(3,PL)\tayrılıyor olmayacaklarmış',
#  'ayrılmak\tV;INFR;FUT;PRSP;INTR;POS;NOM(2,SG)\tayrılacak olacak mıymışsın',
#  'ayrılmak\tV;INFR;FUT;PRSP;INTR;POS;NOM(3,PL)\tayrılacak olacaklar mıymış',
#  'ayrılmak\tV;INFR;FUT;PRSP;POS;DECL;NOM(1,PL)\tayrılacak olacakmışız',
#  'ayrılmak\tV;INFR;PRS;HAB;NEG;INTR;NOM(3,PL)\tayrılmazlar mıymış',
#  'ayrılmak\tV;INFR;PRS;HAB;NEG;INTR;NOM(3,SG)\tayrılmaz mıymış',
#  'ayrılmak\tV;INFR;PRS;PROG;INTR;POS;NOM(3,SG)\tayrılıyor muymuş',
#  'ayrılmak\tV;INFR;PST;PERF;NEG;DECL;NOM(3,SG)\tayrılmamıştı',
#  'ayrılmak\tV;NEC;PRS;PROG;POS;DECL;NOM(1,SG)\tayrılıyor olmalıyım',
#  'ayrılmak\tV;NEC;PST;PROG;NEG;DECL;NOM(3,SG)\tayrılıyor olmamalıydı',
#  'ayrılmak\tV;NEC;PST;PROG;NEG;INTR;NOM(3,SG)\tayrılıyor olmamalı mıydı',
#  'açmak\tV;IND;FUT;NEG;DECL;NOM(3,PL)\taçmayacaklar',
#  'açmak\tV;IND;FUT;PROG;NEG;INTR;NOM(2,SG)\taçıyor olmayacak mısın',
#  'açmak\tV;IND;PRS;PROG;INTR;POS;NOM(2,PL)\taçıyor musunuz',
#  'açmak\tV;IND;PRS;PROG;POS;DECL;NOM(1,SG)\taçıyorum',
#  'açmak\tV;IND;PRS;PROG;POS;DECL;NOM(3,PL)\taçıyorlar',
#  'açmak\tV;IND;PST;HAB;NEG;DECL;NOM(1,PL)\taçmazdık',
#  'açmak\tV;IND;PST;INTR;POS;NOM(2,SG)\taçtın mı',
#  'açmak\tV;IND;PST;NEG;DECL;NOM(2,PL)\taçmadınız',
#  'açmak\tV;IND;PST;NEG;INTR;NOM(2,SG)\taçmadın mı',
#  'açmak\tV;IND;PST;PROG;NEG;DECL;NOM(3,SG)\taçmıyordu',
#  'açmak\tV;IND;PST;PRSP;NEG;INTR;NOM(1,SG)\taçmayacak mıydım',
#  'açmak\tV;IND;PST;PRSP;POS;DECL;NOM(3,PL)\taçacaklardı',
#  'açmak\tV;IND;PST;PRSP;PROG;INTR;POS;NOM(1,PL)\taçıyor olacak mıydık',
#  'açmak\tV;IND;PST;PRSP;PROG;POS;DECL;NOM(1,PL)\taçıyor olacaktık',
#  'açmak\tV;INFR;FUT;HAB;INTR;POS;NOM(3,PL)\taçar olacaklar mıymış',
#  'açmak\tV;INFR;FUT;HAB;POS;DECL;NOM(1,PL)\taçar olacakmışız',
#  'açmak\tV;INFR;FUT;PERF;INTR;POS;NOM(3,SG)\taçmış olacak mı',
#  'açmak\tV;INFR;FUT;PERF;NEG;DECL;NOM(1,PL)\taçmış olmayacağız',
#  'açmak\tV;INFR;FUT;PERF;NEG;INTR;NOM(3,SG)\taçmış olmayacak mı',
#  'açmak\tV;INFR;PRS;PROG;INTR;POS;NOM(1,SG)\taçıyor muymuşum',
#  'açmak\tV;INFR;PST;NEG;DECL;NOM(2,PL)\taçmamışsınız',
#  'açmak\tV;INFR;PST;PERF;NEG;DECL;NOM(2,SG)\taçmamıştın',
#  'açmak\tV;INFR;PST;PERF;NEG;DECL;NOM(3,SG)\taçmamıştı',
#  'açmak\tV;NEC;INFR;PST;NEG;DECL;NOM(3,SG)\taçmamalıymış',
#  'açmak\tV;NEC;INFR;PST;NEG;INTR;NOM(1,PL)\taçmamalı mıymışız',
#  'açmak\tV;NEC;PRS;POS;DECL;NOM(1,SG)\taçmeliyim',
#  'açmak\tV;NEC;PST;PROG;NEG;DECL;NOM(1,SG)\taçıyor olmamalıydım',
#  'açmak\tV;NFIN\taçmak',
#  'ağda yapmak\tV;IMP;POS;DECL;NOM(2,SG)\tağda yap',
#  'ağda yapmak\tV;IND;FUT;INTR;POS;NOM(2,PL)\tağd yapacak mısınız',
#  'ağda yapmak\tV;IND;FUT;NEG;DECL;NOM(1,PL)\tağda yapmayacağız',
#  'ağda yapmak\tV;IND;FUT;NEG;DECL;NOM(3,SG)\tağda yapmayacak',
#  'ağda yapmak\tV;IND;FUT;NEG;INTR;NOM(3,SG)\tağda yapmayacak mı',
#  'ağda yapmak\tV;IND;FUT;PRSP;NEG;INTR;NOM(3,SG)\tağd yapacak olmayacak mı',
#  'ağda yapmak\tV;IND;PST;HAB;POS;DECL;NOM(2,PL)\tağd yapardınız',
#  'ağda yapmak\tV;IND;PST;INTR;POS;NOM(1,SG)\tağda yaptım mı',
#  'ağda yapmak\tV;IND;PST;PERF;INTR;POS;NOM(1,PL)\tağda yaptı mıydık',
#  'ağda yapmak\tV;IND;PST;PROG;NEG;INTR;NOM(1,PL)\tağda yapmıyor muyduk',
#  'ağda yapmak\tV;INFR;FUT;PERF;INTR;POS;NOM(1,SG)\tağda yapmış olacak mıyım',
#  'ağda yapmak\tV;INFR;FUT;PERF;NEG;DECL;NOM(1,PL)\tağda yapmış olmayacağız',
#  'ağda yapmak\tV;INFR;FUT;PERF;NEG;DECL;NOM(2,SG)\tağda yapmış olmayacaksın',
#  'ağda yapmak\tV;INFR;FUT;PERF;POS;DECL;NOM(1,PL)\tağda yapmış olacağız',
#  'ağda yapmak\tV;INFR;FUT;PROG;INTR;POS;NOM(1,PL)\tağd yapıyor olacak mıymışız',
#  'ağda yapmak\tV;INFR;FUT;PRSP;INTR;POS;NOM(1,SG)\tağd yapacak olacak mıymışım',
#  'ağda yapmak\tV;INFR;FUT;PRSP;POS;DECL;NOM(1,PL)\tağd yapacak olacakmışız',
#  'ağda yapmak\tV;INFR;PRS;HAB;INTR;POS;NOM(1,SG)\tağd yapar mıymışım',
#  'ağda yapmak\tV;INFR;PRS;HAB;INTR;POS;NOM(3,PL)\tağd yaparlar mıymış',
#  'ağda yapmak\tV;INFR;PST;PERF;INTR;POS;NOM(2,PL)\tağda yapmış mıydınız',
#  'ağda yapmak\tV;INFR;PST;PERF;NEG;INTR;NOM(1,PL)\tağda yapmamış mıydık',
#  'ağda yapmak\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(2,SG)\tağd yapıyor olmalı mıymışsın',
#  'ağda yapmak\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(3,PL)\tağd yapıyor olmalılar mıymış',
#  'ağda yapmak\tV;NEC;PRS;NEG;INTR;NOM(1,PL)\tağda yapmameli miyiz',
#  'ağda yapmak\tV;NEC;PRS;NEG;INTR;NOM(2,PL)\tağda yapmameli misiniz',
#  'ağda yapmak\tV;NEC;PRS;NEG;INTR;NOM(3,PL)\tağda yapmameliler mi',
#  'ağda yapmak\tV;NEC;PRS;PROG;NEG;DECL;NOM(2,PL)\tağd yapıyor olmamalısınız',
#  'ağda yapmak\tV;NEC;PRS;PROG;NEG;INTR;NOM(1,PL)\tağd yapıyor olmamalı mıyız',
#  'ağlaşmak\tV;IMP;POS;DECL;NOM(2,SG)\tağlaş',
#  'ağlaşmak\tV;IND;FUT;PROG;NEG;DECL;NOM(2,SG)\tağlaşıyor olmayacaksın',
#  'ağlaşmak\tV;IND;FUT;PRSP;NEG;DECL;NOM(3,PL)\tağlaşacak olmayacaklar',
#  'ağlaşmak\tV;IND;PRS;HAB;INTR;POS;NOM(1,SG)\tağlaşır mıyım',
#  'ağlaşmak\tV;IND;PRS;PROG;NEG;DECL;NOM(3,SG)\tağlaşmıyor',
#  'ağlaşmak\tV;IND;PRS;PROG;POS;DECL;NOM(2,SG)\tağlaşıyorsun',
#  'ağlaşmak\tV;IND;PST;HAB;NEG;DECL;NOM(2,PL)\tağlaşmazdınız',
#  'ağlaşmak\tV;IND;PST;HAB;PROG;NEG;INTR;NOM(1,SG)\tağlaşıyor olmaz mıydım',
#  'ağlaşmak\tV;IND;PST;POS;DECL;NOM(2,SG)\tağlaştın',
#  'ağlaşmak\tV;IND;PST;PRSP;POS;DECL;NOM(3,PL)\tağlaşacaklardı',
#  'ağlaşmak\tV;INFR;FUT;HAB;POS;DECL;NOM(1,SG)\tağlaşır olacakmışım',
#  'ağlaşmak\tV;INFR;FUT;NEG;INTR;NOM(3,SG)\tağlaşmayacak mıymış',
#  'ağlaşmak\tV;INFR;FUT;PERF;NEG;INTR;NOM(1,PL)\tağlaşmış olmayacak mıyız',
#  'ağlaşmak\tV;INFR;FUT;PROG;NEG;DECL;NOM(2,SG)\tağlaşıyor olmayacakmışsın',
#  'ağlaşmak\tV;INFR;FUT;PROG;POS;DECL;NOM(1,PL)\tağlaşıyor olacakmışız',
#  'ağlaşmak\tV;INFR;FUT;PRSP;POS;DECL;NOM(3,SG)\tağlaşacak olacakmış',
#  'ağlaşmak\tV;INFR;PRS;HAB;INTR;POS;NOM(3,SG)\tağlaşır mıymış',
#  'ağlaşmak\tV;INFR;PRS;PROG;NEG;INTR;NOM(2,PL)\tağlaşmıyor muymuşsunuz',
#  'ağlaşmak\tV;INFR;PST;INTR;POS;NOM(2,SG)\tağlaşmış mısın',
#  'ağlaşmak\tV;INFR;PST;SG;NEG;INTR;NOM(2)\tağlaşmamış mıymışsın',
#  'ağlaşmak\tV;NEC;INFR;PRS;PROG;POS;DECL;NOM(2,PL)\tağlaşıyor olmalıymışsınız',
#  'ağlaşmak\tV;NEC;INFR;PST;INTR;POS;NOM(2,SG)\tağlaşmalı mıymışsın',
#  'ağlaşmak\tV;NEC;PRS;INTR;POS;NOM(3,PL)\tağlaşmeliler mi',
#  'ağlaşmak\tV;NEC;PRS;PROG;NEG;DECL;NOM(1,SG)\tağlaşıyor olmamalıyım',
#  'ağlaşmak\tV;NEC;PRS;PROG;POS;DECL;NOM(2,SG)\tağlaşıyor olmalısın',
#  'ağlaşmak\tV;NEC;PST;INTR;POS;NOM(1,PL)\tağlaşmalı mıydık',
#  'ağlaşmak\tV;NEC;PST;NEG;DECL;NOM(1,PL)\tağlaşmamalıydık',
#  'aşiret\tN;ABL(PL)\taşiretlerden',
#  'aşiret\tN;ABL(PL;PSS(2,PL))\taşiretlerinizden',
#  'aşiret\tN;ABL(PL;PSS(3,SG))\taşiretlerinden',
#  'aşiret\tN;ABL(SG)\taşiretten',
#  'aşiret\tN;ABL(SG;PSS(1,PL))\taşiretimizden',
#  'aşiret\tN;ABL(SG;PSS(2,PL))\taşiretinizden',
#  'aşiret\tN;ABL(SG;PSS(2,SG))\taşiretinden',
#  'aşiret\tN;ABL(SG;PSS(3,SG))\taşiretinden',
#  'aşiret\tN;ACC(PL;PSS(1,PL))\taşiretlerimizi',
#  'aşiret\tN;ACC(PL;PSS(2,PL))\taşiretlerinizi',
#  'aşiret\tN;ACC(SG;PSS(2,SG))\taşiretini',
#  'aşiret\tN;ACC(SG;PSS(3,SG))\taşiretini',
#  'aşiret\tN;DAT(PL;PSS(1,PL))\taşiretlerimize',
#  'aşiret\tN;DAT(PL;PSS(2,PL))\taşiretlerinize',
#  'aşiret\tN;DAT(SG;PSS(1,PL))\taşiretimize',
#  'aşiret\tN;DAT(SG;PSS(2,PL))\taşiretinize',
#  'aşiret\tN;DAT(SG;PSS(3,SG))\taşiretine',
#  'aşiret\tN;GEN(PL;PSS(1,PL))\taşiretlerimizin',
#  'aşiret\tN;GEN(SG;PSS(2,PL))\taşiretinizin',
#  'aşiret\tN;LOC(PL)\taşiretlerde',
#  'aşiret\tN;LOC(PL;PSS(2,PL))\taşiretlerinizde',
#  'aşiret\tN;LOC(PL;PSS(3,SG))\taşiretlerinde',
#  'aşiret\tN;LOC(SG;PSS(2,SG))\taşiretinde',
#  'aşiret\tN;LOC(SG;PSS(3,SG))\taşiretinde',
#  'aşiret\tN;NOM(PL)\taşiretler',
#  'aşiret\tN;NOM(PL;PSS(1,PL))\taşiretlerimiz',
#  'aşiret\tN;NOM(PL;PSS(3,SG))\taşiretleri',
#  'aşiret\tN;NOM(SG;PSS(2,SG))\taşiretin',
#  'aşmak\tV;IND;FUT;INTR;POS;NOM(2,SG)\taşacak mısın',
#  'aşmak\tV;IND;FUT;NEG;DECL;NOM(2,SG)\taşmayacaksın',
#  'aşmak\tV;IND;FUT;NEG;DECL;NOM(3,SG)\taşmayacak',
#  'aşmak\tV;IND;FUT;POS;DECL;NOM(1,PL)\taşacağız',
#  'aşmak\tV;IND;FUT;PROG;INTR;POS;NOM(3,SG)\taşıyor olacak mı',
#  'aşmak\tV;IND;FUT;PROG;NEG;INTR;NOM(2,SG)\taşıyor olmayacak mısın',
#  'aşmak\tV;IND;FUT;PRSP;POS;DECL;NOM(3,SG)\taşacak olacak',
#  'aşmak\tV;IND;PRS;HAB;POS;DECL;NOM(1,SG)\taşarım',
#  'aşmak\tV;IND;PST;HAB;NEG;INTR;NOM(1,PL)\taşmaz mıydık',
#  'aşmak\tV;IND;PST;HAB;PROG;INTR;POS;NOM(1,SG)\taşıyor olur muydum',
#  'aşmak\tV;IND;PST;HAB;PROG;NEG;DECL;NOM(3,PL)\taşıyor olmazlardı',
#  'aşmak\tV;IND;PST;HAB;PROG;NEG;DECL;NOM(3,SG)\taşıyor olmazdı',
#  'aşmak\tV;IND;PST;NEG;INTR;NOM(2,PL)\taşmadınız mı',
#  'aşmak\tV;IND;PST;PERF;INTR;POS;NOM(2,PL)\taştı mıydınız',
#  'aşmak\tV;IND;PST;PRSP;NEG;DECL;NOM(2,SG)\taşmayacaktın',
#  'aşmak\tV;INFR;FUT;HAB;NEG;INTR;NOM(2,SG)\taşar olmayacak mıymışsın',
#  'aşmak\tV;INFR;FUT;HAB;POS;DECL;NOM(3,SG)\taşar olacakmış',
#  'aşmak\tV;INFR;FUT;NEG;DECL;NOM(3,SG)\taşmayacakmış',
#  'aşmak\tV;INFR;FUT;PROG;NEG;DECL;NOM(3,PL)\taşıyor olmayacaklarmış',
#  'aşmak\tV;INFR;FUT;PRSP;NEG;DECL;NOM(3,SG)\taşacak olmayacakmış',
#  'aşmak\tV;INFR;FUT;PRSP;NEG;INTR;NOM(3,PL)\taşacak olmayacaklar mıymış',
#  'aşmak\tV;INFR;PRS;HAB;NEG;DECL;NOM(2,PL)\taşmazmışsınız',
#  'aşmak\tV;INFR;PRS;HAB;POS;DECL;NOM(1,PL)\taşarmışız',
#  'aşmak\tV;INFR;PRS;PROG;INTR;POS;NOM(2,PL)\taşıyor muymuşsunuz',
#  'aşmak\tV;INFR;PST;NEG;DECL;NOM(3,SG)\taşmamış',
#  'aşmak\tV;INFR;PST;SG;NEG;INTR;NOM(1)\taşmamış mıymışım',
#  'aşmak\tV;NEC;INFR;PST;POS;DECL;NOM(1,PL)\taşmalıymışız',
#  'aşmak\tV;NEC;PRS;PROG;INTR;POS;NOM(2,SG)\taşıyor olmalı mısın',
#  'aşure\tN;ABL(PL;PSS(3,SG))\taşurelerinden',
#  'aşure\tN;ABL(SG;PSS(1,PL))\taşuremizden',
#  'aşure\tN;ABL(SG;PSS(3,SG))\taşuresinden',
#  'aşure\tN;ACC(PL;PSS(2,PL))\taşurelerinizi',
#  'aşure\tN;ACC(PL;PSS(3,SG))\taşurelerini',
#  'aşure\tN;ACC(SG;PSS(1,PL))\taşuremizi',
#  'aşure\tN;ACC(SG;PSS(2,PL))\taşurenizi',
#  'aşure\tN;ACC(SG;PSS(2,SG))\taşureni',
#  'aşure\tN;ACC(SG;PSS(3,SG))\taşuresini',
#  'aşure\tN;DAT(PL)\taşurelere',
#  'aşure\tN;DAT(PL;PSS(2,SG))\taşurelerine',
#  'aşure\tN;DAT(SG;PSS(1,PL))\taşuremize',
#  'aşure\tN;DAT(SG;PSS(2,SG))\taşurene',
#  'aşure\tN;DAT(SG;PSS(3,SG))\taşuresine',
#  'aşure\tN;GEN(PL)\taşurelerin',
#  'aşure\tN;GEN(PL;PSS(2,PL))\taşurelerinizin',
#  'aşure\tN;GEN(SG)\taşurenin',
#  'aşure\tN;GEN(SG;PSS(3,SG))\taşuresinin',
#  'aşure\tN;LOC(PL)\taşurelerde',
#  'aşure\tN;LOC(PL;PSS(2,SG))\taşurelerinde',
#  'aşure\tN;LOC(PL;PSS(3,SG))\taşurelerinde',
#  'aşure\tN;LOC(SG;PSS(1,PL))\taşuremizde',
#  'aşure\tN;NOM(PL;PSS(2,PL))\taşureleriniz',
#  'aşure\tN;NOM(PL;PSS(3,SG))\taşureleri',
#  'aşure\tN;NOM(SG)\taşure',
#  'aşure\tN;NOM(SG;PSS(1,PL))\taşuremiz',
#  'aşure\tN;NOM(SG;PSS(2,PL))\taşureniz',
#  'aşure\tN;NOM(SG;PSS(3,SG))\taşuresi',
#  'aşık\tN;ABL(PL)\taşıklardan',
#  'aşık\tN;ABL(PL;PSS(1,PL))\taşıklarımızdan',
#  'aşık\tN;ABL(SG;PSS(2,SG))\taşığından',
#  'aşık\tN;ABL(SG;PSS(3,SG))\taşığından',
#  'aşık\tN;ACC(PL)\taşıkları',
#  'aşık\tN;ACC(PL;PSS(3,SG))\taşıklarını',
#  'aşık\tN;ACC(SG;PSS(2,PL))\taşığınızı',
#  'aşık\tN;DAT(PL)\taşıklara',
#  'aşık\tN;DAT(PL;PSS(2,PL))\taşıklarınıza',
#  'aşık\tN;DAT(PL;PSS(2,SG))\taşıklarına',
#  'aşık\tN;DAT(SG)\taşığa',
#  'aşık\tN;GEN(PL;PSS(3,SG))\taşıklarının',
#  'aşık\tN;GEN(SG;PSS(2,SG))\taşığının',
#  'aşık\tN;LOC(SG;PSS(2,SG))\taşığında',
#  'aşık\tN;NOM(SG;PSS(3,SG))\taşığı',
#  'aşık\tN;PL;IND;PST;NOM(2,PL)\taşıklardınız',
#  'aşık\tN;PL;IND;PST;NOM(3,SG)\taşıklardı',
#  'aşık\tN;PL;INFR;PST;NOM(1,SG)\taşıklarmışım',
#  'aşık\tN;PL;PRS;NOM(1,PL)\taşıklarız',
#  'aşık\tN;PL;PRS;NOM(1,SG)\taşıklarım',
#  'aşık\tN;PL;PRS;NOM(2,PL)\taşıklarsınız',
#  'aşık\tN;PL;PRS;NOM(2,SG)\taşıklarsın',
#  'aşık\tN;SG;IND;PST;NOM(1,SG)\taşıkdım',
#  'aşık\tN;SG;IND;PST;NOM(2,PL)\taşıkdınız',
#  'aşık\tN;SG;INFR;PST;NOM(1,PL)\taşıkmışız',
#  'aşık\tN;SG;INFR;PST;NOM(2,SG)\taşıkmışsın',
#  'aşık\tN;SG;INFR;PST;NOM(3,PL)\taşıkmışlar',
#  'aşık\tN;SG;PRS;NOM(3,PL)\taşıklar',
#  'babalık testi\tN;ABL(PL)\tbabalık testlerinden',
#  'babalık testi\tN;ABL(SG)\tbabalık testinden',
#  'babalık testi\tN;ACC(PL)\tbabalık testlerini',
#  'babalık testi\tN;ACC(SG)\tbabalık testini',
#  'babalık testi\tN;DAT(PL)\tbabalık testlerine',
#  'babalık testi\tN;DAT(SG)\tbabalık testine',
#  'babalık testi\tN;GEN(PL)\tbabalık testlerinin',
#  'babalık testi\tN;GEN(SG)\tbabalık testinin',
#  'babalık testi\tN;LOC(PL)\tbabalık testlerinde',
#  'babalık testi\tN;LOC(SG)\tbabalık testinde',
#  'babalık testi\tN;NOM(PL)\tbabalık testleri',
#  'babalık testi\tN;NOM(SG)\tbabalık testi',
#  'baklava\tN;ABL(PL;PSS(3,SG))\tbaklavalarından',
#  'baklava\tN;ABL(SG;PSS(1,PL))\tbaklavamızdan',
#  'baklava\tN;ABL(SG;PSS(2,SG))\tbaklavandan',
#  'baklava\tN;ACC(PL;PSS(2,SG))\tbaklavalarını',
#  'baklava\tN;ACC(PL;PSS(3,SG))\tbaklavalarını',
#  'baklava\tN;ACC(SG;PSS(1,PL))\tbaklavamızı',
#  'baklava\tN;ACC(SG;PSS(2,PL))\tbaklavanızı',
#  'baklava\tN;ACC(SG;PSS(3,SG))\tbaklavasını',
#  'baklava\tN;DAT(PL;PSS(1,PL))\tbaklavalarımıza',
#  'baklava\tN;DAT(PL;PSS(3,SG))\tbaklavalarına',
#  'baklava\tN;DAT(SG;PSS(2,SG))\tbaklavana',
#  'baklava\tN;GEN(PL)\tbaklavaların',
#  'baklava\tN;GEN(PL;PSS(2,PL))\tbaklavalarınızın',
#  'baklava\tN;GEN(PL;PSS(3,SG))\tbaklavalarının',
#  'baklava\tN;GEN(SG)\tbaklavanın',
#  'baklava\tN;GEN(SG;PSS(2,SG))\tbaklavanın',
#  'baklava\tN;GEN(SG;PSS(3,SG))\tbaklavasının',
#  'baklava\tN;LOC(PL;PSS(1,PL))\tbaklavalarımızda',
#  'baklava\tN;LOC(PL;PSS(3,SG))\tbaklavalarında',
#  'baklava\tN;LOC(SG)\tbaklavada',
#  'baklava\tN;LOC(SG;PSS(1,PL))\tbaklavamızda',
#  'baklava\tN;LOC(SG;PSS(2,SG))\tbaklavanda',
#  'baklava\tN;LOC(SG;PSS(3,SG))\tbaklavasında',
#  'baklava\tN;NOM(PL;PSS(1,PL))\tbaklavalarımız',
#  'baklava\tN;NOM(PL;PSS(2,PL))\tbaklavalarınız',
#  'baklava\tN;NOM(SG;PSS(1,PL))\tbaklavamız',
#  'baklava\tN;NOM(SG;PSS(2,PL))\tbaklavanız',
#  'baklava\tN;NOM(SG;PSS(3,SG))\tbaklavası',
#  'bandaj\tN;ABL(PL;PSS(2,SG))\tbandajlarından',
#  'bandaj\tN;ABL(SG)\tbandajdan',
#  'bandaj\tN;ABL(SG;PSS(1,PL))\tbandajımızdan',
#  'bandaj\tN;ABL(SG;PSS(3,SG))\tbandajından',
#  'bandaj\tN;ACC(PL;PSS(1,PL))\tbandajlarımızı',
#  'bandaj\tN;ACC(PL;PSS(2,PL))\tbandajlarınızı',
#  'bandaj\tN;ACC(PL;PSS(2,SG))\tbandajlarını',
#  'bandaj\tN;ACC(PL;PSS(3,SG))\tbandajlarını',
#  'bandaj\tN;ACC(SG;PSS(2,PL))\tbandajınızı',
#  'bandaj\tN;ACC(SG;PSS(2,SG))\tbandajını',
#  'bandaj\tN;DAT(PL;PSS(2,PL))\tbandajlarınıza',
#  'bandaj\tN;DAT(SG)\tbandaja',
#  'bandaj\tN;DAT(SG;PSS(1,PL))\tbandajımıza',
#  'bandaj\tN;DAT(SG;PSS(2,PL))\tbandajınıza',
#  'bandaj\tN;GEN(PL)\tbandajların',
#  'bandaj\tN;GEN(PL;PSS(2,PL))\tbandajlarınızın',
#  'bandaj\tN;GEN(PL;PSS(2,SG))\tbandajlarının',
#  'bandaj\tN;GEN(SG;PSS(1,PL))\tbandajımızın',
#  'bandaj\tN;GEN(SG;PSS(3,SG))\tbandajının',
#  'bandaj\tN;LOC(PL;PSS(2,PL))\tbandajlarınızda',
#  'bandaj\tN;LOC(PL;PSS(2,SG))\tbandajlarında',
#  'bandaj\tN;LOC(PL;PSS(3,SG))\tbandajlarında',
#  'bandaj\tN;LOC(SG;PSS(2,PL))\tbandajınızda',
#  'bandaj\tN;LOC(SG;PSS(2,SG))\tbandajında',
#  'bandaj\tN;LOC(SG;PSS(3,SG))\tbandajında',
#  'bandaj\tN;NOM(SG)\tbandaj',
#  'bandaj\tN;NOM(SG;PSS(1,PL))\tbandajımız',
#  'bandaj\tN;NOM(SG;PSS(3,SG))\tbandajı',
#  'batmak\tV;IND;FUT;NEG;DECL;NOM(3,SG)\tbatmayacak',
#  'batmak\tV;IND;FUT;NEG;INTR;NOM(1,PL)\tbatmayacak mıyız',
#  'batmak\tV;IND;FUT;PRSP;NEG;INTR;NOM(1,SG)\tbatacak olmayacak mıyım',
#  'batmak\tV;IND;PRS;HAB;POS;DECL;NOM(1,PL)\tbatarız',
#  'batmak\tV;IND;PRS;PROG;NEG;INTR;NOM(1,SG)\tbatmıyor muyum',
#  'batmak\tV;IND;PRS;PROG;POS;DECL;NOM(3,PL)\tbatıyorlar',
#  'batmak\tV;IND;PST;HAB;INTR;POS;NOM(3,PL)\tbatarlar mıydı',
#  'batmak\tV;IND;PST;HAB;NEG;DECL;NOM(2,SG)\tbatmazdın',
#  'batmak\tV;IND;PST;INTR;POS;NOM(2,PL)\tbattınız mı',
#  'batmak\tV;IND;PST;PERF;INTR;POS;NOM(3,SG)\tbattı mıydı',
#  'batmak\tV;IND;PST;POS;DECL;NOM(2,SG)\tbattın',
#  'batmak\tV;IND;PST;PRSP;INTR;POS;NOM(1,SG)\tbatacak mıydım',
#  'batmak\tV;IND;PST;PRSP;PROG;NEG;DECL;NOM(1,PL)\tbatıyor olmayacaktık',
#  'batmak\tV;INFR;FUT;HAB;INTR;POS;NOM(2,PL)\tbatar olacak mıymışsınız',
#  'batmak\tV;INFR;FUT;HAB;NEG;DECL;NOM(3,SG)\tbatar olmayacakmış',
#  'batmak\tV;INFR;FUT;HAB;POS;DECL;NOM(2,PL)\tbatar olacakmışsınız',
#  'batmak\tV;INFR;FUT;PERF;NEG;INTR;NOM(3,PL)\tbatmış olmayacaklar mı',
#  'batmak\tV;INFR;FUT;PROG;NEG;INTR;NOM(3,PL)\tbatıyor olmayacaklar mıymış',
#  'batmak\tV;INFR;PST;PERF;NEG;INTR;NOM(1,PL)\tbatmamış mıydık',
#  'batmak\tV;INFR;PST;PERF;NEG;INTR;NOM(3,SG)\tbatmamış mıydı',
#  'batmak\tV;INFR;PST;PL;NEG;INTR;NOM(3)\tbatmamışlar mıymış',
#  'batmak\tV;INFR;PST;PRSP;NEG;DECL;NOM(3,SG)\tbatmış olmayacaktı',
#  'batmak\tV;INFR;PST;PRSP;NEG;INTR;NOM(2,SG)\tbatmış olmayacak mıydın',
#  'batmak\tV;INFR;PST;SG;POS;DECL;NOM(3)\tbatmışmış',
#  'batmak\tV;NEC;INFR;PRS;PROG;NEG;INTR;NOM(2,SG)\tbatıyor olmamalı mıymışsın',
#  'batmak\tV;NEC;PRS;NEG;DECL;NOM(3,SG)\tbatmameli',
#  'batmak\tV;NEC;PRS;POS;DECL;NOM(1,SG)\tbatmeliyim',
#  'batmak\tV;NEC;PST;PROG;POS;DECL;NOM(2,SG)\tbatıyor olmalıydın',
#  'başarmak\tV;IND;FUT;INTR;POS;NOM(1,PL)\tbaşaracak mıyız',
#  'başarmak\tV;IND;FUT;NEG;INTR;NOM(1,SG)\tbaşarmayacak mıyım',
#  'başarmak\tV;IND;FUT;PRSP;POS;DECL;NOM(2,SG)\tbaşaracak olacaksın',
#  'başarmak\tV;IND;PRS;PROG;POS;DECL;NOM(2,SG)\tbaşarıyorsun',
#  'başarmak\tV;IND;PST;HAB;NEG;INTR;NOM(2,PL)\tbaşarmaz mıydınız',
#  'başarmak\tV;IND;PST;HAB;PROG;NEG;INTR;NOM(2,PL)\tbaşarıyor olmaz mıydınız',
#  'başarmak\tV;IND;PST;INTR;POS;NOM(2,PL)\tbaşardınız mı',
#  'başarmak\tV;IND;PST;PERF;NEG;INTR;NOM(3,SG)\tbaşarmadı mıydı',
#  'başarmak\tV;IND;PST;PRSP;INTR;POS;NOM(3,PL)\tbaşaracaklar mıydı',
#  'başarmak\tV;IND;PST;PRSP;PROG;POS;DECL;NOM(3,PL)\tbaşarıyor olacaklardı',
#  'başarmak\tV;INFR;FUT;HAB;NEG;DECL;NOM(1,SG)\tbaşarır olmayacakmışım',
#  'başarmak\tV;INFR;FUT;HAB;POS;DECL;NOM(2,PL)\tbaşarır olacakmışsınız',
#  'başarmak\tV;INFR;FUT;NEG;DECL;NOM(3,SG)\tbaşarmayacakmış',
#  'başarmak\tV;INFR;FUT;NEG;INTR;NOM(1,PL)\tbaşarmayacak mıymışız',
#  'başarmak\tV;INFR;FUT;PERF;NEG;INTR;NOM(1,SG)\tbaşarmış olmayacak mıyım',
#  'başarmak\tV;INFR;PRS;HAB;POS;DECL;NOM(2,SG)\tbaşarırmışsın',
#  'başarmak\tV;INFR;PRS;PROG;NEG;DECL;NOM(3,SG)\tbaşarmıyormuş',
#  'başarmak\tV;INFR;PRS;PROG;NEG;INTR;NOM(3,SG)\tbaşarmıyor muymuş',
#  'başarmak\tV;INFR;PST;PERF;INTR;POS;NOM(1,SG)\tbaşarmış mıydım',
#  'başarmak\tV;INFR;PST;PERF;NEG;INTR;NOM(3,SG)\tbaşarmamış mıydı',
#  'başarmak\tV;INFR;PST;PERF;POS;DECL;NOM(2,PL)\tbaşarmıştınız',
#  'başarmak\tV;INFR;PST;PERF;POS;DECL;NOM(2,SG)\tbaşarmıştın',
#  'başarmak\tV;NEC;INFR;PRS;PROG;NEG;DECL;NOM(1,SG)\tbaşarıyor olmamalıymışım',
#  'başarmak\tV;NEC;PRS;INTR;POS;NOM(1,PL)\tbaşarmeli miyiz',
#  'başarmak\tV;NEC;PRS;POS;DECL;NOM(1,PL)\tbaşarmeliyiz',
#  'başarmak\tV;NEC;PST;PROG;NEG;INTR;NOM(1,SG)\tbaşarıyor olmamalı mıydım',
#  'beklemek\tV;IND;FUT;NEG;DECL;NOM(1,PL)\tbeklemeyeceğiz',
#  'beklemek\tV;IND;FUT;PROG;NEG;DECL;NOM(3,PL)\tbekliyor olmayacaklar',
#  'beklemek\tV;IND;PRS;HAB;POS;DECL;NOM(1,SG)\tbeklerim',
#  'beklemek\tV;IND;PST;HAB;PROG;NEG;DECL;NOM(1,PL)\tbekliyor olmazdık',
#  'beklemek\tV;IND;PST;HAB;PROG;NEG;INTR;NOM(1,PL)\tbekliyor olmaz mıydık',
#  'beklemek\tV;IND;PST;NEG;DECL;NOM(1,SG)\tbeklemedim',
#  'beklemek\tV;IND;PST;PROG;NEG;INTR;NOM(1,SG)\tbeklemiyor muydum',
#  'beklemek\tV;IND;PST;PROG;NEG;INTR;NOM(2,PL)\tbeklemiyor muydunuz',
#  'beklemek\tV;IND;PST;PRSP;NEG;INTR;NOM(2,PL)\tbeklemeyecek miydiniz',
#  'beklemek\tV;INFR;FUT;HAB;NEG;DECL;NOM(2,PL)\tbekler olmayacakmışsınız',
#  'beklemek\tV;INFR;FUT;HAB;POS;DECL;NOM(2,SG)\tbekler olacakmışsın',
#  'beklemek\tV;INFR;FUT;NEG;DECL;NOM(1,PL)\tbeklemeyecekmişiz',
#  'beklemek\tV;INFR;FUT;PERF;INTR;POS;NOM(2,SG)\tbeklemiş olacak mısın',
#  'beklemek\tV;INFR;FUT;PERF;NEG;DECL;NOM(1,PL)\tbeklemiş olmayacağız',
#  'beklemek\tV;INFR;FUT;PROG;INTR;POS;NOM(3,PL)\tbekliyor olacaklar mıymış',
#  'beklemek\tV;INFR;FUT;PROG;POS;DECL;NOM(1,PL)\tbekliyor olacakmışız',
#  'beklemek\tV;INFR;FUT;PRSP;INTR;POS;NOM(1,PL)\tbekleecek olacak mıymışız',
#  'beklemek\tV;INFR;FUT;PRSP;NEG;DECL;NOM(2,PL)\tbekleecek olmayacakmışsınız',
#  'beklemek\tV;INFR;PRS;HAB;INTR;POS;NOM(1,SG)\tbekler miymişim',
#  'beklemek\tV;INFR;PRS;PROG;INTR;POS;NOM(3,SG)\tbekliyor muymuş',
#  'beklemek\tV;INFR;PRS;PROG;NEG;DECL;NOM(1,PL)\tbeklemiyormuşuz',
#  'beklemek\tV;INFR;PST;NEG;DECL;NOM(3,SG)\tbeklememiş',
#  'beklemek\tV;INFR;PST;PERF;NEG;DECL;NOM(3,PL)\tbeklememişlerdi',
#  'beklemek\tV;INFR;PST;PRSP;INTR;POS;NOM(1,SG)\tbeklemiş olacak mıydım',
#  'beklemek\tV;NEC;INFR;PST;INTR;POS;NOM(1,PL)\tbeklemeli miymişiz',
#  'beklemek\tV;NEC;PRS;PROG;INTR;POS;NOM(3,PL)\tbekliyor olmalılar mı',
#  'beklemek\tV;NEC;PST;POS;DECL;NOM(3,PL)\tbeklemelilerdi',
#  'beklemek\tV;NEC;PST;PROG;INTR;POS;NOM(1,PL)\tbekliyor olmalı mıydık',
#  'bencillik\tN;ABL(PL)\tbencilliklerden',
#  'bencillik\tN;ABL(SG)\tbencillikten',
#  'bencillik\tN;ACC(PL)\tbencillikleri',
#  'bencillik\tN;ACC(SG)\tbencilliği',
#  'bencillik\tN;DAT(PL)\tbencilliklere',
#  'bencillik\tN;DAT(SG)\tbencilliğe',
#  'bencillik\tN;GEN(PL)\tbencilliklerin',
#  'bencillik\tN;GEN(SG)\tbencilliğin',
#  'bencillik\tN;LOC(PL)\tbencilliklerde',
#  'bencillik\tN;LOC(SG)\tbencillikte',
#  'bencillik\tN;NOM(PL)\tbencillikler',
#  'bencillik\tN;NOM(SG)\tbencillik',
#  'benzemek\tV;IMP;NEG;DECL;NOM(2,SG)\tbenzeme',
#  'benzemek\tV;IND;FUT;INTR;POS;NOM(1,PL)\tbenzeyecek miyiz',
#  'benzemek\tV;IND;FUT;PROG;INTR;POS;NOM(2,SG)\tbenziyor olacak mısın',
#  'benzemek\tV;IND;PRS;HAB;NEG;INTR;NOM(1,SG)\tbenzemez miyim',
#  'benzemek\tV;IND;PST;HAB;NEG;DECL;NOM(3,SG)\tbenzemezdi',
#  'benzemek\tV;IND;PST;HAB;NEG;INTR;NOM(2,PL)\tbenzemez miydiniz',
#  'benzemek\tV;IND;PST;HAB;PROG;INTR;POS;NOM(3,SG)\tbenziyor olur muydu',
#  'benzemek\tV;IND;PST;NEG;DECL;NOM(1,SG)\tbenzemedim',
#  'benzemek\tV;IND;PST;PROG;INTR;POS;NOM(2,SG)\tbenziyor muydun',
#  'benzemek\tV;IND;PST;PROG;NEG;INTR;NOM(2,PL)\tbenzemiyor muydunuz',
#  'benzemek\tV;IND;PST;PRSP;INTR;POS;NOM(1,PL)\tbenzeyecek miydik',
#  'benzemek\tV;IND;PST;PRSP;PROG;NEG;DECL;NOM(1,SG)\tbenziyor olmayacaktım',
#  'benzemek\tV;IND;PST;PRSP;PROG;POS;DECL;NOM(3,PL)\tbenziyor olacaklardı',
#  'benzemek\tV;INFR;FUT;PRSP;INTR;POS;NOM(2,PL)\tbenzeecek olacak mıymışsınız',
#  'benzemek\tV;INFR;FUT;PRSP;INTR;POS;NOM(3,SG)\tbenzeecek olacak mıymış',
#  'benzemek\tV;INFR;PRS;HAB;POS;DECL;NOM(1,PL)\tbenzermişiz',
#  'benzemek\tV;INFR;PRS;HAB;POS;DECL;NOM(1,SG)\tbenzermişim',
#  'benzemek\tV;INFR;PRS;PROG;NEG;INTR;NOM(3,PL)\tbenzemiyorlar mıymış',
#  'benzemek\tV;INFR;PST;PERF;POS;DECL;NOM(3,PL)\tbenzemişlerdi',
#  'benzemek\tV;INFR;PST;PL;INTR;POS;NOM(3)\tbenzemişler miymiş',
#  'benzemek\tV;INFR;PST;PRSP;INTR;POS;NOM(2,SG)\tbenzemiş olacak mıydın',
#  'benzemek\tV;NEC;INFR;PRS;PROG;NEG;DECL;NOM(2,PL)\tbenziyor olmamalıymışsınız',
#  'benzemek\tV;NEC;INFR;PRS;PROG;NEG;DECL;NOM(2,SG)\tbenziyor olmamalıymışsın',
#  'benzemek\tV;NEC;PRS;POS;DECL;NOM(1,SG)\tbenzemeliyim',
#  'benzemek\tV;NEC;PRS;PROG;NEG;DECL;NOM(3,PL)\tbenziyor olmamalılar',
#  'benzemek\tV;NEC;PST;POS;DECL;NOM(3,SG)\tbenzemeliydi',
#  'benzemek\tV;NEC;PST;PROG;INTR;POS;NOM(2,SG)\tbenziyor olmalı mıydın',
#  'benzemek\tV;NEC;PST;PROG;NEG;DECL;NOM(1,SG)\tbenziyor olmamalıydım',
#  'bildirmek\tV;IND;FUT;PROG;INTR;POS;NOM(1,PL)\tbildiriyor olacak mıyız',
#  'bildirmek\tV;IND;FUT;PROG;POS;DECL;NOM(3,SG)\tbildiriyor olacak',
#  'bildirmek\tV;IND;PST;HAB;INTR;POS;NOM(1,PL)\tbildirir miydik',
#  'bildirmek\tV;IND;PST;HAB;POS;DECL;NOM(3,SG)\tbildirirdi',
#  'bildirmek\tV;IND;PST;HAB;PROG;NEG;INTR;NOM(3,PL)\tbildiriyor olmazlar mıydı',
#  'bildirmek\tV;IND;PST;PERF;NEG;INTR;NOM(2,PL)\tbildirmedi miydiniz',
#  'bildirmek\tV;IND;PST;PRSP;NEG;DECL;NOM(1,SG)\tbildirmeyecektim',
#  'bildirmek\tV;IND;PST;PRSP;NEG;DECL;NOM(3,PL)\tbildirmeyeceklerdi',
#  'bildirmek\tV;IND;PST;PRSP;PROG;POS;DECL;NOM(3,PL)\tbildiriyor olacaklardı',
#  'bildirmek\tV;INFR;FUT;HAB;INTR;POS;NOM(3,PL)\tbildirir olacaklar mıymış',
#  'bildirmek\tV;INFR;FUT;HAB;NEG;INTR;NOM(1,SG)\tbildirir olmayacak mıymışım',
#  'bildirmek\tV;INFR;FUT;NEG;DECL;NOM(1,SG)\tbildirmeyecekmişim',
#  'bildirmek\tV;INFR;FUT;NEG;INTR;NOM(3,SG)\tbildirmeyecek miymiş',
#  'bildirmek\tV;INFR;FUT;POS;DECL;NOM(3,PL)\tbildireceklermiş',
#  'bildirmek\tV;INFR;FUT;PROG;NEG;DECL;NOM(3,PL)\tbildiriyor olmayacaklarmış',
#  'bildirmek\tV;INFR;PRS;HAB;INTR;POS;NOM(1,SG)\tbildirir miymişim',
#  'bildirmek\tV;INFR;PRS;PROG;INTR;POS;NOM(3,SG)\tbildiriyor muymuş',
#  'bildirmek\tV;INFR;PRS;PROG;NEG;INTR;NOM(1,PL)\tbildirmiyor muymuşuz',
#  'bildirmek\tV;INFR;PST;NEG;INTR;NOM(1,SG)\tbildirmemiş miyim',
#  'bildirmek\tV;INFR;PST;PRSP;NEG;DECL;NOM(1,SG)\tbildirmiş olmayacaktım',
#  'bildirmek\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(1,SG)\tbildiriyor olmalı mıymışım',
#  'bildirmek\tV;NEC;INFR;PRS;PROG;INTR;POS;NOM(3,PL)\tbildiriyor olmalılar mıymış',
#  'bildirmek\tV;NEC;INFR;PST;POS;DECL;NOM(2,SG)\tbildirmeliymişsin',
#  'bildirmek\tV;NEC;PRS;INTR;POS;NOM(3,SG)\tbildirmeli mi',
#  'bildirmek\tV;NEC;PRS;NEG;DECL;NOM(1,PL)\tbildirmemeliyiz',
#  'bildirmek\tV;NEC;PRS;PROG;NEG;INTR;NOM(3,SG)\tbildiriyor olmamalı mı',
#  'bildirmek\tV;NEC;PRS;PROG;POS;DECL;NOM(1,PL)\tbildiriyor olmalıyız',
#  'bildirmek\tV;NEC;PST;POS;DECL;NOM(3,PL)\tbildirmelilerdi',
#  'bilemek\tV;IND;FUT;INTR;POS;NOM(3,PL)\tbileyecekler mi',
#  'bilemek\tV;IND;FUT;PRSP;POS;DECL;NOM(1,PL)\tbileyecek olacağız',
#  'bilemek\tV;IND;PRS;PROG;INTR;POS;NOM(1,SG)\tbiliyor muyum',
#  'bilemek\tV;IND;PST;HAB;INTR;POS;NOM(2,PL)\tbiler miydiniz',
#  'bilemek\tV;IND;PST;HAB;POS;DECL;NOM(1,PL)\tbilerdik',
#  'bilemek\tV;IND;PST;HAB;PROG;POS;DECL;NOM(1,PL)\tbiliyor olurduk',
#  'bilemek\tV;IND;PST;PERF;NEG;DECL;NOM(2,PL)\tbilemediydiniz',
#  'bilemek\tV;IND;PST;PROG;NEG;INTR;NOM(2,SG)\tbilemiyor muydun',
#  'bilemek\tV;IND;PST;PRSP;INTR;POS;NOM(2,PL)\tbileyecek miydiniz',
#  'bilemek\tV;IND;PST;PRSP;PROG;NEG;INTR;NOM(2,PL)\tbiliyor olmayacak mıydınız',
#  'bilemek\tV;INFR;FUT;INTR;POS;NOM(1,PL)\tbileyecek miymişiz',
#  'bilemek\tV;INFR;FUT;PERF;NEG;INTR;NOM(1,PL)\tbilemiş olmayacak mıyız',
#  'bilemek\tV;INFR;FUT;PERF;NEG;INTR;NOM(2,SG)\tbilemiş olmayacak mısın',
#  'bilemek\tV;INFR;PRS;HAB;INTR;POS;NOM(3,PL)\tbilerler miymiş',
#  'bilemek\tV;INFR;PRS;HAB;NEG;INTR;NOM(2,SG)\tbilemez miymişsin',
#  'bilemek\tV;INFR;PST;PL;NEG;DECL;NOM(1)\tbilememişmişiz',
#  'bilemek\tV;NEC;INFR;PRS;PROG;POS;DECL;NOM(2,SG)\tbiliyor olmalıymışsın',
#  'bilemek\tV;NEC;INFR;PST;INTR;POS;NOM(2,SG)\tbilemeli miymişsin',
#  'bilemek\tV;NEC;INFR;PST;NEG;DECL;NOM(1,PL)\tbilememeliymişiz',
#  'bilemek\tV;NEC;INFR;PST;NEG;INTR;NOM(3,SG)\tbilememeli miymiş',
#  'bilemek\tV;NEC;PRS;NEG;INTR;NOM(2,PL)\tbilememeli misiniz',
#  'bilemek\tV;NEC;PRS;POS;DECL;NOM(1,PL)\tbilemeliyiz',
#  'bilemek\tV;NEC;PRS;PROG;NEG;DECL;NOM(1,SG)\tbiliyor olmamalıyım',
#  'bilemek\tV;NEC;PST;NEG;DECL;NOM(2,SG)\tbilememeliydin',
#  'bilemek\tV;NEC;PST;PROG;POS;DECL;NOM(3,PL)\tbiliyor olmalılardı',
#  'bilim teorisi\tN;ABL(SG)\tbilim teorisinden',
#  'bilim teorisi\tN;ACC(PL)\tbilim teorilerini',
#  'bilim teorisi\tN;ACC(SG)\tbilim teorisini',
#  'bilim teorisi\tN;DAT(PL)\tbilim teorilerine',
#  'bilim teorisi\tN;DAT(SG)\tbilim teorisine',
#  'bilim teorisi\tN;GEN(PL)\tbilim teorilerinin',
#  'bilim teorisi\tN;GEN(SG)\tbilim teorisinin',
#  'bilim teorisi\tN;LOC(PL)\tbilim teorilerinde',
#  'bilim teorisi\tN;LOC(SG)\tbilim teorisinde',
#  'bilim teorisi\tN;NOM(PL)\tbilim teorileri',
#  'bilim teorisi\tN;NOM(SG)\tbilim teorisi',
#  'binmek\tV;IND;FUT;NEG;DECL;NOM(2,PL)\tbinmeyeceksiniz',
#  'binmek\tV;IND;PRS;HAB;INTR;POS;NOM(1,SG)\tbiner miyim',
#  'binmek\tV;IND;PRS;HAB;NEG;INTR;NOM(1,SG)\tbinmez miyim',
#  'binmek\tV;IND;PRS;PROG;NEG;DECL;NOM(2,PL)\tbinmiyorsunuz',
#  'binmek\tV;IND;PRS;PROG;POS;DECL;NOM(3,PL)\tbiniyorlar',
#  'binmek\tV;IND;PST;HAB;POS;DECL;NOM(1,PL)\tbinerdik',
#  'binmek\tV;IND;PST;HAB;PROG;NEG;INTR;NOM(1,SG)\tbiniyor olmaz mıydım',
#  'binmek\tV;IND;PST;PERF;INTR;POS;NOM(2,PL)\tbindi miydiniz',
#  'binmek\tV;IND;PST;PERF;INTR;POS;NOM(3,SG)\tbindi miydi',
#  'binmek\tV;IND;PST;PERF;NEG;INTR;NOM(3,SG)\tbinmedi miydi',
#  'binmek\tV;IND;PST;PRSP;NEG;DECL;NOM(2,PL)\tbinmeyecektiniz',
#  'binmek\tV;IND;PST;PRSP;NEG;DECL;NOM(3,PL)\tbinmeyeceklerdi',
#  'binmek\tV;INFR;FUT;PERF;NEG;INTR;NOM(2,PL)\tbinmiş olmayacak mısınız',
#  'binmek\tV;INFR;FUT;PERF;NEG;INTR;NOM(3,SG)\tbinmiş olmayacak mı',
#  'binmek\tV;INFR;FUT;PROG;POS;DECL;NOM(3,SG)\tbiniyor olacakmış',
#  'binmek\tV;INFR;FUT;PRSP;INTR;POS;NOM(2,SG)\tbinecek olacak mıymışsın',
#  'binmek\tV;INFR;FUT;PRSP;NEG;DECL;NOM(1,SG)\tbinecek olmayacakmışım',
#  'binmek\tV;INFR;PRS;HAB;INTR;POS;NOM(3,SG)\tbiner miymiş',
#  'binmek\tV;INFR;PRS;HAB;NEG;INTR;NOM(1,PL)\tbinmez miymişiz',
#  'binmek\tV;INFR;PRS;HAB;NEG;INTR;NOM(2,SG)\tbinmez miymişsin',
#  'binmek\tV;INFR;PRS;PROG;INTR;POS;NOM(1,PL)\tbiniyor muymuşuz',
#  'binmek\tV;INFR;PST;NEG;DECL;NOM(2,SG)\tbinmemişsin',
#  'binmek\tV;INFR;PST;PRSP;NEG;DECL;NOM(1,SG)\tbinmiş olmayacaktım',
#  'binmek\tV;INFR;PST;PRSP;NEG;DECL;NOM(2,PL)\tbinmiş olmayacaktınız',
#  'binmek\tV;NEC;PRS;INTR;POS;NOM(2,SG)\tbinmeli misin',
#  'binmek\tV;NEC;PRS;NEG;DECL;NOM(1,SG)\tbinmemeliyim',
#  ...]

# %% [markdown]
# ### Testing for prefixing/suffixing (lines 193-201)
#
# Now let's look at the first chunk of code that tests if a language is predominantly suffixing or prefixing: lines 193-201.
#
# ```python
#         # First, test if language is predominantly suffixing or prefixing
#         # If prefixing, work with reversed strings
#         prefbias, suffbias = 0,0
#         for l in lines:
#             lemma, _, form = l.split(u'\t')
#             aligned = halign(lemma, form)
#             if ' ' not in aligned[0] and ' ' not in aligned[1] and '-' not in aligned[0] and '-' not in aligned[1]:
#                 prefbias += numleadingsyms(aligned[0],'_') + numleadingsyms(aligned[1],'_')
#                 suffbias += numtrailingsyms(aligned[0],'_') + numtrailingsyms(aligned[1],'_')
# ```
#
# Line 195 initializes two variables to the integer 0. What do you think these variables are for?
#
# ```python
#         prefbias, suffbias = 0,0
# ```
#
# Then we have a for loop that iterates over each line in `lines`.
#
# To better understand what's going on in the for loop, we can see what happens when we run through a single iteration of the loop.

# %%
# let's try out the the for loop on a random, single entry of lines
rand_line_ind = random.randint(0,len(lines))
l0 = lines[rand_line_ind] 
lemma, _, form = l0.split(u'\t')

print(lemma)
print(_) # why use underscore as a variable name?
print(form)
# Out:
# büktürülmek
# V;IND;FUT;PROG;POS;DECL;NOM(2,PL)
# büktürülüyor olacaksınız

# %%
# CODE BLOCK FOR CALLING halign()
# We'll come back to the details of halign() later
aligned = nonneural.halign(lemma, form)

print(aligned)
# Out:
# ('büktürülmek_____________', 'büktürülüyor olacaksınız')

# %%
# CODE BLOCK FOR LINES 199-201
prefbias, suffbias = 0,0

if ' ' not in aligned[0] and ' ' not in aligned[1] and '-' not in aligned[0] and '-' not in aligned[1]:
    prefbias += nonneural.numleadingsyms(aligned[0],'_') + nonneural.numleadingsyms(aligned[1],'_')
    suffbias += nonneural.numtrailingsyms(aligned[0],'_') + nonneural.numtrailingsyms(aligned[1],'_')

print(nonneural.numleadingsyms(aligned[0],'_'))
print(nonneural.numleadingsyms(aligned[1],'_'))
print(nonneural.numtrailingsyms(aligned[0],'_'))
print(nonneural.numtrailingsyms(aligned[1],'_'))

print("prefbias = ", prefbias)
print("suffbias = ", suffbias)
# Out:
# 0
# 0
# 13
# 0
# prefbias =  0
# suffbias =  0

# %% [markdown]
# ### Extracting transformation rules (lines 202-224)
#
# Now let's take a look at the "extracting transformation rules" part.
#
# The first chunk of code does something based on whether `prefbias` or `suffbias` is greater.
#
# ```python
# lemma, msd, form = l.split(u'\t')
#             if prefbias > suffbias:
#                 lemma = lemma[::-1]
#                 form = form[::-1]
# ```
#
# We can try it out on our test line.

# %%
# CODE BLOCK FOR TESTING LINES 202-206

print("Reminder: prefbias =", prefbias)
print("Reminder: suffbias =", suffbias)

lemma, msd, form = l0.split(u'\t')
print("lemma:", lemma, "\nmsd:", msd, "\nform:", form)

if prefbias > suffbias:
    lemma = lemma[::-1]
    print(lemma)
    form = form[::-1]
    print(form)
# Out:
# Reminder: prefbias = 0
# Reminder: suffbias = 0
# lemma: büktürülmek
# msd: V;IND;FUT;PROG;POS;DECL;NOM(2,PL)
# form: büktürülüyor olacaksınız

# %% [markdown]
# Line 207 then calls `prefix_suffix_rules_get()`
#
# ```python
#             prules, srules = prefix_suffix_rules_get(lemma, form)
# ```
#
# We can try it out on our test line.

# %%
prules, srules = nonneural.prefix_suffix_rules_get(lemma, form)
print("prules:", prules)
print("\n")
print("srules:", srules)
# Out:
# prules: {('<büktürülüyor ola', '<büktürülüyor ola'), ('<büktürü', '<büktürü'), ('<büktürülüyor olac', '<büktürülüyor olac'), ('<büktürülüyo', '<büktürülüyo'), ('<büktürülüyor ', '<büktürülüyor '), ('<büktürülüyor', '<büktürülüyor'), ('<bü', '<bü'), ('<büktü', '<büktü'), ('<bük', '<bük'), ('<büktürül', '<büktürül'), ('<büktürülüyor olaca', '<büktürülüyor olaca'), ('<büktürülüyor ol', '<büktürülüyor ol'), ('<büktürülüy', '<büktürülüy'), ('<bükt', '<bükt'), ('<', '<'), ('<b', '<b'), ('<büktürülüyor o', '<büktürülüyor o'), ('<büktürülü', '<büktürülü'), ('<büktür', '<büktür')}
#
#
# srules: {('k>', 'acaksınız>'), ('>', 'ınız>'), ('büktürülmek>', 'büktürülüyor olacaksınız>'), ('k>', 'or olacaksınız>'), ('k>', 'olacaksınız>'), ('türülmek>', 'türülüyor olacaksınız>'), ('lmek>', 'lüyor olacaksınız>'), ('k>', 'r olacaksınız>'), ('mek>', 'üyor olacaksınız>'), ('k>', 'ksınız>'), ('k>', 'caksınız>'), ('>', 'nız>'), ('k>', 'aksınız>'), ('>', 'sınız>'), ('ktürülmek>', 'ktürülüyor olacaksınız>'), ('k>', ' olacaksınız>'), ('ek>', 'yor olacaksınız>'), ('>', 'z>'), ('rülmek>', 'rülüyor olacaksınız>'), ('ürülmek>', 'ürülüyor olacaksınız>'), ('üktürülmek>', 'üktürülüyor olacaksınız>'), ('ülmek>', 'ülüyor olacaksınız>'), ('>', '>'), ('k>', 'lacaksınız>'), ('>', 'ız>')}

# %% [markdown]
# The next code chunk (line 209-212) does something with `allprules` and `allsrules` (initialized in line 188):
#
# ```python
#             if msd not in allprules and len(prules) > 0:
#                 allprules[msd] = {}
#             if msd not in allsrules and len(srules) > 0:
#                 allsrules[msd] = {}
#
# ```
#
# Let's try it out.

# %%
allprules, allsrules = {}, {}  # from line 188

print("Reminder: msd=", msd)

if msd not in allprules and len(prules) > 0:
    allprules[msd] = {}
if msd not in allsrules and len(srules) > 0:
    allsrules[msd] = {}

print("allprules:", allprules)
print("allsrules:", allprules)
# Out:
# Reminder: msd= V;IND;FUT;PROG;POS;DECL;NOM(2,PL)
# allprules: {'V;IND;FUT;PROG;POS;DECL;NOM(2,PL)': {}}
# allsrules: {'V;IND;FUT;PROG;POS;DECL;NOM(2,PL)': {}}

# %% [markdown]
# Then we have two code chunks that seem to do something similar to `prules` and `srules`:
#
# ```python
#
#             for r in prules:
#                 if (r[0],r[1]) in allprules[msd]:
#                     allprules[msd][(r[0],r[1])] = allprules[msd][(r[0],r[1])] + 1
#                 else:
#                     allprules[msd][(r[0],r[1])] = 1
#
#             for r in srules:
#                 if (r[0],r[1]) in allsrules[msd]:
#                     allsrules[msd][(r[0],r[1])] = allsrules[msd][(r[0],r[1])] + 1
#                 else:
#                     allsrules[msd][(r[0],r[1])] = 1
#
#
# ```
#
# Let's try out the prules chunk:

# %%
# CODE BLOCK FOR prules SECTION

print("Reminder: msd =", msd)
print("Reminder: prules =", prules, "\n")

print("Reminder: allprules =", allprules)
print("Reminder: allprules[msd] =", allprules[msd], "\n")


for r in prules:
    if (r[0],r[1]) in allprules[msd]:
        allprules[msd][(r[0],r[1])] = allprules[msd][(r[0],r[1])] + 1
    else:
        allprules[msd][(r[0],r[1])] = 1

print("Now allprules[msd] is:", allprules[msd])
# Out:
# Reminder: msd = V;IND;FUT;PROG;POS;DECL;NOM(2,PL)
# Reminder: prules = {('<büktürülüyor ola', '<büktürülüyor ola'), ('<büktürü', '<büktürü'), ('<büktürülüyor olac', '<büktürülüyor olac'), ('<büktürülüyo', '<büktürülüyo'), ('<büktürülüyor ', '<büktürülüyor '), ('<büktürülüyor', '<büktürülüyor'), ('<bü', '<bü'), ('<büktü', '<büktü'), ('<bük', '<bük'), ('<büktürül', '<büktürül'), ('<büktürülüyor olaca', '<büktürülüyor olaca'), ('<büktürülüyor ol', '<büktürülüyor ol'), ('<büktürülüy', '<büktürülüy'), ('<bükt', '<bükt'), ('<', '<'), ('<b', '<b'), ('<büktürülüyor o', '<büktürülüyor o'), ('<büktürülü', '<büktürülü'), ('<büktür', '<büktür')}
#
# Reminder: allprules = {'V;IND;FUT;PROG;POS;DECL;NOM(2,PL)': {}}
# Reminder: allprules[msd] = {}
#
# Now allprules[msd] is: {('<büktürülüyor ola', '<büktürülüyor ola'): 1, ('<büktürü', '<büktürü'): 1, ('<büktürülüyor olac', '<büktürülüyor olac'): 1, ('<büktürülüyo', '<büktürülüyo'): 1, ('<büktürülüyor ', '<büktürülüyor '): 1, ('<büktürülüyor', '<büktürülüyor'): 1, ('<bü', '<bü'): 1, ('<büktü', '<büktü'): 1, ('<bük', '<bük'): 1, ('<büktürül', '<büktürül'): 1, ('<büktürülüyor olaca', '<büktürülüyor olaca'): 1, ('<büktürülüyor ol', '<büktürülüyor ol'): 1, ('<büktürülüy', '<büktürülüy'): 1, ('<bükt', '<bükt'): 1, ('<', '<'): 1, ('<b', '<b'): 1, ('<büktürülüyor o', '<büktürülüyor o'): 1, ('<büktürülü', '<büktürülü'): 1, ('<büktür', '<büktür'): 1}

# %%
# CODE BLOCK FOR srules SECTION
print("Reminder: msd =", msd)
print("Reminder: srules =", srules, "\n")

print("Reminder: allsrules =", allsrules)
print("Reminder: allsrules[msd] =", allsrules[msd], "\n")


for r in srules:
    if (r[0],r[1]) in allsrules[msd]:
        allsrules[msd][(r[0],r[1])] = allsrules[msd][(r[0],r[1])] + 1
    else:
        allsrules[msd][(r[0],r[1])] = 1

print("Now allsrules[msd] is:", allsrules[msd])
# Out:
# Reminder: msd = V;IND;FUT;PROG;POS;DECL;NOM(2,PL)
# Reminder: srules = {('k>', 'acaksınız>'), ('>', 'ınız>'), ('büktürülmek>', 'büktürülüyor olacaksınız>'), ('k>', 'or olacaksınız>'), ('k>', 'olacaksınız>'), ('türülmek>', 'türülüyor olacaksınız>'), ('lmek>', 'lüyor olacaksınız>'), ('k>', 'r olacaksınız>'), ('mek>', 'üyor olacaksınız>'), ('k>', 'ksınız>'), ('k>', 'caksınız>'), ('>', 'nız>'), ('k>', 'aksınız>'), ('>', 'sınız>'), ('ktürülmek>', 'ktürülüyor olacaksınız>'), ('k>', ' olacaksınız>'), ('ek>', 'yor olacaksınız>'), ('>', 'z>'), ('rülmek>', 'rülüyor olacaksınız>'), ('ürülmek>', 'ürülüyor olacaksınız>'), ('üktürülmek>', 'üktürülüyor olacaksınız>'), ('ülmek>', 'ülüyor olacaksınız>'), ('>', '>'), ('k>', 'lacaksınız>'), ('>', 'ız>')}
#
# Reminder: allsrules = {'V;IND;FUT;PROG;POS;DECL;NOM(2,PL)': {}}
# Reminder: allsrules[msd] = {}
#
# Now allsrules[msd] is: {('k>', 'acaksınız>'): 1, ('>', 'ınız>'): 1, ('büktürülmek>', 'büktürülüyor olacaksınız>'): 1, ('k>', 'or olacaksınız>'): 1, ('k>', 'olacaksınız>'): 1, ('türülmek>', 'türülüyor olacaksınız>'): 1, ('lmek>', 'lüyor olacaksınız>'): 1, ('k>', 'r olacaksınız>'): 1, ('mek>', 'üyor olacaksınız>'): 1, ('k>', 'ksınız>'): 1, ('k>', 'caksınız>'): 1, ('>', 'nız>'): 1, ('k>', 'aksınız>'): 1, ('>', 'sınız>'): 1, ('ktürülmek>', 'ktürülüyor olacaksınız>'): 1, ('k>', ' olacaksınız>'): 1, ('ek>', 'yor olacaksınız>'): 1, ('>', 'z>'): 1, ('rülmek>', 'rülüyor olacaksınız>'): 1, ('ürülmek>', 'ürülüyor olacaksınız>'): 1, ('üktürülmek>', 'üktürülüyor olacaksınız>'): 1, ('ülmek>', 'ülüyor olacaksınız>'): 1, ('>', '>'): 1, ('k>', 'lacaksınız>'): 1, ('>', 'ız>'): 1}

# %% [markdown]
# ## The `halign()` function
#
# What does the `halign()` function do?
# We can print out the function definition:

# %%
# From https://stackoverflow.com/questions/1562759/can-python-print-a-function-definition
import inspect
import sys
sys.stdout.write(inspect.getsource(nonneural.halign))
# Out:
# def halign(s,t):
#     """Align two strings by Hamming distance."""
#     slen = len(s)
#     tlen = len(t)
#     minscore = len(s) + len(t) + 1
#     for upad in range(0, len(t)+1):
#         upper = '_' * upad + s + (len(t) - upad) * '_'
#         lower = len(s) * '_' + t
#         score = hamming(upper, lower)
#         if score < minscore:
#             bu = upper
#             bl = lower
#             minscore = score
#
#     for lpad in range(0, len(s)+1):
#         upper = len(t) * '_' + s
#         lower = (len(s) - lpad) * '_' + t + '_' * lpad
#         score = hamming(upper, lower)
#         if score < minscore:
#             bu = upper
#             bl = lower
#             minscore = score
#
#     zipped = list(zip(bu,bl))
#     newin  = ''.join(i for i,o in zipped if i != '_' or o != '_')
#     newout = ''.join(o for i,o in zipped if i != '_' or o != '_')
#     return newin, newout
# 858
